# %% [markdown]
# # DH Refined Diagnostics — 20260714_v1985 (post-2000, re-fit cells run)
#
# Final-selection notebook for the post-2000 **refined** evaluate run, repointed at
# `02-evaluate/20260714_v1985_refined/` — the structure-C cells run (s1 free, s2 free &
# independent, `s2 ⊇ bulk ⊇ tail`). Fork of
# `20260515/dh_refined_diagnostics_post2000.ipynb`.
#
# Picks up where `dh_intermediate_diagnostics.ipynb` left off. The S1/S2/Bulk/Tail
# family/exposure decisions are baked into the refined grid by
# `build_refined_specs_post2000.py`; this notebook starts at the assembled-DH layer
# and works entirely off `dh_results.parquet` — it does **not** read
# `model_predictions/` (the run used `--skip-model-predictions`).
#
# **Convergence gate removed:** the re-fit-in-evaluate pipeline has no separate fit
# stage and writes no per-component `.json` sidecars, so the IS/OOS convergence gate
# from the 20260517 version is not applicable and has been dropped.
#
# Flow:
# 1. Load the refined `dh_results.parquet` and aggregate to one row per config (OOS).
# 2. Asymmetric calibration gate (`full_pred_obs_ratio_oos ∈ [0.1, 1.5]`) + non-finite OOS cull.
# 3. Per-rule winner trajectories by threshold.
# 4. Pick metrics → Kendall τ → Borda / TOPSIS → winners-by-covariate-chain.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from idd_tc_mortality.select.model_query import ModelQuery
from idd_tc_mortality.select.model_selection import (
    CONFIG_COLS,
    DEFAULT_METRICS,
    CALIBRATION_METRICS,
    prepare_rankings_df,
    borda_rank,
    pareto_frontier,
    topsis_rank,
    pairwise_dominance_summary,
    cluster_configurations,
    winner_profile,
    kendall_tau_heatmap,
    prune_redundant_metrics
)
from idd_tc_mortality.viz.stage_plots import StagePlotter

# Reuse the qmd's helper module for shared heatmap / winner-panel plots.
sys.path.insert(0, str(Path('../..').resolve() / 'reports'))
import _helpers as H

# %matplotlib inline
plt.rcParams['figure.dpi'] = 100
pd.options.display.max_columns = 80
pd.options.display.width = 160

# %% [markdown]
# ## Paths
#
# Edit the dates to point at the refined run you want to inspect.

# %%
ROOT      = Path('/mnt/team/idd/pub/idd_tc_mortality')
EVAL_DATE = '20260714_v1985_refined'   # structure-C refined cells run
DATA_DATE = '20260714_v1985'           # post-2000 input.parquet (years >= 2000)

RESULTS_PATH = ROOT / '02-evaluate' / EVAL_DATE / 'dh_results.parquet'
EVAL_DIR     = ROOT / '02-evaluate' / EVAL_DATE
DATA_PATH    = ROOT / '00-data'     / DATA_DATE / 'input.parquet'
SPECS_PATH   = ROOT / '01-refined'  / DATA_DATE / 'refined_is_specs.json'  # 336 IS specs (reference only)

for p in (RESULTS_PATH, EVAL_DIR, DATA_PATH):
    assert p.exists(), f'Missing: {p}'
print('All paths resolve.')
# Out:
# All paths resolve.

# %% [markdown]
# ## Load

# %%
dh_results = pd.read_parquet(RESULTS_PATH)
data       = pd.read_parquet(DATA_PATH)

print(f'dh_results : {dh_results.shape[0]:,} rows × {dh_results.shape[1]} cols')
print(f'training   : {data.shape[0]:,} rows × {data.shape[1]} cols')
print(f'fold_tags  : {dh_results["fold_tag"].value_counts().to_dict()}')
print(f'configs    : {dh_results.groupby(CONFIG_COLS, dropna=False).ngroups:,} unique')
print(f'thresholds : {sorted(dh_results["threshold_quantile"].unique())}')
# Out:
# dh_results : 1,376,256 rows × 252 cols
# training   : 3,024 rows × 13 cols
# fold_tags  : {'insample': 229376, 'oos_seed0': 229376, 'oos_seed1': 229376, 'oos_seed2': 229376, 'oos_seed3': 229376, 'oos_seed4': 229376}
# configs    : 229,376 unique
# thresholds : [np.float64(0.7), np.float64(0.75), np.float64(0.7999999999999999), np.float64(0.85)]

# %% [markdown]
# ## Build the rankings dataframe
#
# `prepare_rankings_df(..., subset='oos')` gives one row per config with OOS
# metrics averaged across seeds. This is the canonical input to all ranking
# methods below.
#
# Then we cull: drop configs with any non-finite OOS metric (failed folds)
# and configs outside the calibration gate. Tighten or loosen the cull as
# needed.

# %%
df_oos = prepare_rankings_df(dh_results, subset='oos')
print(f'{len(df_oos):,} configurations before any cull')
# Out:
# 229,376 configurations before any cull

# %%
print(f'Before cull: {len(df_oos):,} configs')

# Drop configs with any non-finite OOS metric (failed folds).
oos_numeric = [c for c in df_oos.columns
               if c.endswith('_oos') and pd.api.types.is_numeric_dtype(df_oos[c])]
finite_mask = np.isfinite(df_oos[oos_numeric].to_numpy()).all(axis=1)
n_failed = int((~finite_mask).sum())
df_oos = df_oos[finite_mask].copy()
print(f'After non-finite cull: {len(df_oos):,} configs ({n_failed:,} dropped as failures)')

# Asymmetric calibration gate — under-prediction (mega-event honesty)
# allowed; over-prediction (compensating bulk overpred) capped tighter.
# See preliminary_decisions_post2000.qmd §Scope.
RATIO_BOUNDS = (0.05, 1.1)
df_oos = df_oos[df_oos['full_pred_obs_ratio_oos'].between(*RATIO_BOUNDS)].copy()
print(f'After calibration gate [{RATIO_BOUNDS[0]}, {RATIO_BOUNDS[1]}]: '
      f'{len(df_oos):,} configs')

print('\nPost-cull count per threshold:')
print(df_oos['threshold_quantile'].value_counts().sort_index().to_string())
# Out:
# Before cull: 229,376 configs
# After non-finite cull: 229,280 configs (96 dropped as failures)
# After calibration gate [0.05, 1.1]: 222,194 configs
#
# Post-cull count per threshold:
# threshold_quantile
# 0.70    57344
# 0.75    57344
# 0.80    57248
# 0.85    50258

# %% [markdown]
# ### Convergence gate — N/A for the re-fit pipeline
#
# The 20260517 version scanned per-component `{component_id}.json` sidecars in the
# fit directory for an IRLS/optimiser `converged` flag. The re-fit-in-evaluate
# pipeline has **no fit stage and writes no sidecars** — each component is re-fit
# in-memory by the evaluate worker, and convergence is not persisted to
# `dh_results.parquet`. So this gate is dropped; `df_oos` after the calibration gate
# above is the final candidate pool.

# %% [markdown]
# ## Per-rule winner trajectories
#
# Same diagnostic as the preliminary qmd's Threshold section, on the refined
# survivor pool. For each threshold, six configs are identified — the one
# that wins at coverage level 1, 5, 10, 15, 20 (argmax of
# `full_coverage_rate_L_oos`), and the one that wins on the mean across all
# 20 levels — and their full 1..20 trajectories are plotted. Each level-winner
# gets a dot at the level where it was picked.

# %%
winner_records = H.threshold_winner_panels(df_oos)
plt.show()

print('\nWinner configs per (threshold, rule):')
print(winner_records.to_string(index=False))
# Out:
# Winner configs per (threshold, rule):
#  threshold      rule s1_family s1_exposure_mode                                                                 s1_cov s2_family s2_exposure_mode                                                                  s2_cov  bulk_family bulk_exposure_mode                                                                bulk_cov  tail_family tail_exposure_mode                                                                tail_cov
#       0.70  best @ 1     logit             free   {"basin": true, "is_island": true, "sdi": true, "wind_speed": false}     logit             free    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit               free    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true}      weibull               free    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true}
#       0.70  best @ 5     logit             free   {"basin": true, "is_island": true, "sdi": true, "wind_speed": false}     logit             free    {"basin": true, "is_island": true, "sdi": false, "wind_speed": true} scaled_logit               free  {"basin": false, "is_island": true, "sdi": false, "wind_speed": false} log_logistic             weight  {"basin": false, "is_island": true, "sdi": false, "wind_speed": false}
#       0.70 best @ 10     logit             free   {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight   {"basin": false, "is_island": true, "sdi": true, "wind_speed": false} log_logistic             weight  {"basin": false, "is_island": true, "sdi": false, "wind_speed": false}
#       0.70 best @ 15     logit             free  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false}     logit             free    {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight   {"basin": false, "is_island": false, "sdi": true, "wind_speed": true} log_logistic             weight  {"basin": false, "is_island": false, "sdi": false, "wind_speed": true}
#       0.70 best @ 20     logit             free  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false}     logit             free     {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic             weight    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true}
#       0.70  best avg     logit             free   {"basin": true, "is_island": true, "sdi": true, "wind_speed": false}     logit             free     {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic             weight   {"basin": false, "is_island": true, "sdi": false, "wind_speed": true}
#       0.75  best @ 1     logit             free  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false}     logit             free   {"basin": false, "is_island": true, "sdi": true, "wind_speed": false} scaled_logit               free   {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}          gpd        free+weight   {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}
#       0.75  best @ 5     logit             free  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false}     logit             free    {"basin": true, "is_island": true, "sdi": false, "wind_speed": true} scaled_logit               free  {"basin": false, "is_island": true, "sdi": false, "wind_speed": false} log_logistic        free+weight  {"basin": false, "is_island": true, "sdi": false, "wind_speed": false}
#       0.75 best @ 10     logit             free   {"basin": true, "is_island": true, "sdi": true, "wind_speed": false}     logit             free     {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic             weight   {"basin": false, "is_island": true, "sdi": false, "wind_speed": true}
#       0.75 best @ 15     logit             free  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false}     logit             free     {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic             weight   {"basin": false, "is_island": true, "sdi": false, "wind_speed": true}
#       0.75 best @ 20     logit             free  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false}     logit             free    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic             weight    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true}
#       0.75  best avg     logit             free  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false}     logit             free     {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight     {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} log_logistic             weight   {"basin": false, "is_island": true, "sdi": false, "wind_speed": true}
#       0.80  best @ 1     logit             free  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false}     logit             free {"basin": false, "is_island": false, "sdi": false, "wind_speed": false} scaled_logit               free {"basin": false, "is_island": false, "sdi": false, "wind_speed": false}          gpd        free+weight {"basin": false, "is_island": false, "sdi": false, "wind_speed": false}
#       0.80  best @ 5     logit             free   {"basin": true, "is_island": true, "sdi": true, "wind_speed": false}     logit             free   {"basin": true, "is_island": true, "sdi": false, "wind_speed": false} scaled_logit        free+weight  {"basin": false, "is_island": true, "sdi": false, "wind_speed": false}          gpd             weight  {"basin": false, "is_island": true, "sdi": false, "wind_speed": false}
#       0.80 best @ 10     logit             free    {"basin": true, "is_island": true, "sdi": true, "wind_speed": true}     logit             free    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true}          gpd             weight  {"basin": false, "is_island": true, "sdi": false, "wind_speed": false}
#       0.80 best @ 15     logit             free {"basin": true, "is_island": false, "sdi": false, "wind_speed": false}     logit             free     {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight   {"basin": false, "is_island": false, "sdi": true, "wind_speed": true} log_logistic        free+weight  {"basin": false, "is_island": false, "sdi": true, "wind_speed": false}
#       0.80 best @ 20     logit             free  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false}     logit             free    {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight   {"basin": false, "is_island": false, "sdi": true, "wind_speed": true} log_logistic        free+weight  {"basin": false, "is_island": false, "sdi": true, "wind_speed": false}
#       0.80  best avg     logit             free   {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free   {"basin": false, "is_island": true, "sdi": true, "wind_speed": false} scaled_logit        free+weight   {"basin": false, "is_island": true, "sdi": true, "wind_speed": false} log_logistic        free+weight   {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}
#       0.85  best @ 1     logit             free  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false}     logit             free  {"basin": false, "is_island": true, "sdi": false, "wind_speed": false} scaled_logit               free  {"basin": false, "is_island": true, "sdi": false, "wind_speed": false} log_logistic               free  {"basin": false, "is_island": true, "sdi": false, "wind_speed": false}
#       0.85  best @ 5     logit             free  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false}     logit             free  {"basin": false, "is_island": true, "sdi": false, "wind_speed": false} scaled_logit               free {"basin": false, "is_island": false, "sdi": false, "wind_speed": false} log_logistic        free+weight {"basin": false, "is_island": false, "sdi": false, "wind_speed": false}
#       0.85 best @ 10     logit             free  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false}     logit             free     {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight   {"basin": false, "is_island": true, "sdi": true, "wind_speed": false} log_logistic        free+weight {"basin": false, "is_island": false, "sdi": false, "wind_speed": false}
#       0.85 best @ 15     logit             free   {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic        free+weight  {"basin": false, "is_island": true, "sdi": false, "wind_speed": false}
#       0.85 best @ 20     logit             free    {"basin": true, "is_island": true, "sdi": true, "wind_speed": true}     logit             free    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic        free+weight  {"basin": false, "is_island": true, "sdi": false, "wind_speed": false}
#       0.85  best avg     logit             free  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false}     logit             free    {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight   {"basin": false, "is_island": false, "sdi": true, "wind_speed": true} log_logistic        free+weight {"basin": false, "is_island": false, "sdi": false, "wind_speed": false}

# %% [markdown]
# ## Pick your own metrics
#
# The 13-metric `DEFAULT_METRICS` is just a starting point. Edit the dict
# below — comment / uncomment lines — to define the set used downstream.
# Both the Kendall heatmap and the ranking step use whatever you set as
# `metrics_present` and `calib_present` here.
#
# Direction:
# - `'lower'`  → smaller is better
# - `'higher'` → larger is better
# - `'calib'`  → closer to 1.0 is better (handled separately by the ranking API)

# %%
metrics_to_use = {
    # ---- S1 (binary: P(deaths >= 1)) ----
    's1_auroc_oos':                  'higher',
    # 's1_brier_oos':                'lower',
    # 's1_fpr_oos':                  'lower',
    # 's1_fnr_oos':                  'lower',

    # ---- S2 (binary: P(rate >= thresh | deaths >= 1)) ----
    's2_auroc_oos':                  'higher',
    # 's2_brier_oos':                'lower',

    # ---- Bulk (regression on rate < thresh) ----
    'bulk_mae_rate_oos':             'lower',
    # 'bulk_rmse_rate_oos':          'lower',
    # 'bulk_cor_rate_oos':           'higher',

    # ---- Tail (regression on rate >= thresh) ----
    'tail_mae_rate_oos':             'lower',
    # 'tail_rmse_rate_oos':          'lower',
    # 'tail_cor_rate_oos':           'higher',

    # ---- Full (unconditional E[rate], applies to every row) ----
    'full_mae_rate_oos':             'lower',
    # 'full_rmse_rate_oos':            'lower',
    # 'full_cor_rate_oos':             'higher',
    # 'full_zero_acc_oos':             'higher',
    'full_pred_obs_ratio_oos':       'calib',
    'full_coverage_rate_10_oos':     'higher',
    'full_coverage_count_10_oos':     'higher',

    # ---- Forward (stage-conditional aggregate) ----
    'fwd_mae_rate_oos':              'lower',
    #'fwd_pred_obs_ratio_oos':        'calib',
    # 'fwd_coverage_rate_10_oos':      'higher',
    # 'fwd_coverage_count_10_oos':      'higher',
}

calib_present   = [k for k, v in metrics_to_use.items()
                   if v == 'calib' and k in df_oos.columns]
# metrics_present = {k: v for k, v in metrics_to_use.items()
#                    if v != 'calib' and k in df_oos.columns}
metrics_present = {k: v for k, v in metrics_to_use.items()
                   if k in df_oos.columns}

print(f'Active rank metrics ({len(metrics_present)}):')
for m, d in metrics_present.items():
    print(f'  {m:35s}  {d}')
print(f'\nActive calibration metrics ({len(calib_present)}):')
for c in calib_present:
    print(f'  {c}  (closer to 1.0)')

missing = [k for k in metrics_to_use if k not in df_oos.columns]
if missing:
    print(f'\n[note] {len(missing)} requested metrics not in df_oos (skipped): {missing}')
# Out:
# Active rank metrics (9):
#   s1_auroc_oos                         higher
#   s2_auroc_oos                         higher
#   bulk_mae_rate_oos                    lower
#   tail_mae_rate_oos                    lower
#   full_mae_rate_oos                    lower
#   full_pred_obs_ratio_oos              calib
#   full_coverage_rate_10_oos            higher
#   full_coverage_count_10_oos           higher
#   fwd_mae_rate_oos                     lower
#
# Active calibration metrics (1):
#   full_pred_obs_ratio_oos  (closer to 1.0)

# %% [markdown]
# ## Kendall τ — metric correlation
#
# Rank correlation between metrics on the culled candidate pool. Tightly
# correlated metrics (high τ) are redundant for ranking purposes; an
# uncorrelated metric adds independent information.

# %%
print(f'Computing rank correlations on {len(df_oos):,} configs × '
      f'{len(metrics_present)} metrics')
tau_df = kendall_tau_heatmap(df_oos, metrics_present, calib_present)
metrics_present, prune_log = prune_redundant_metrics(tau_df, metrics_present, threshold=0.7)
tau_df = kendall_tau_heatmap(df_oos, metrics_present, calib_present)
plt.show()
# Out:
# Computing rank correlations on 222,194 configs × 9 metrics
# === Metric Agreement Analysis ===
# Average pairwise Kendall tau: -0.004
# Pairs with negative correlation: 16
# Low agreement. Flat top tier may be aggregation artifact (metric cancellation).
# step 1: |τ|=0.756  bulk_mae_rate_oos (0.211) vs tail_mae_rate_oos (0.186)  → drop bulk_mae_rate_oos
# step 2: |τ|=0.723  full_mae_rate_oos (0.197) vs fwd_mae_rate_oos (0.183)  → drop full_mae_rate_oos
# === Metric Agreement Analysis ===
# Average pairwise Kendall tau: -0.030
# Pairs with negative correlation: 9
# Low agreement. Flat top tier may be aggregation artifact (metric cancellation).

# %% [markdown]
# ## Winners by method
#
# Borda → TOPSIS → Pareto frontier (first row) → pairwise dominance. Each
# method picks one top config; the table compares them on a shared metric set.

# %%
borda_df, _    = borda_rank(df_oos,    metrics_present, calib_present)
# Out:
# === Borda Count Summary ===
# Total models: 222194
# Metrics used: 7
# Suggested cutpoint: rank 191891 (top 191891 models)
# Top tier Borda range: 384557.0 - 947061.0
# Bottom tier starts at: 947064.5

# %%
top_borda_df = borda_df[borda_df['borda_rank'] <= 281].copy()
# table of quantile, tail_family, and covariate configuration
summary_quality = (top_borda_df
    .groupby(['threshold_quantile', 'tail_family', 'tail_exposure_mode', 'bulk_exposure_mode'])
    .agg(
        n_configs=('borda_rank', 'count'),
        median_rank=('borda_rank', 'median'),
        min_rank=('borda_rank', 'min'),
        max_rank=('borda_rank', 'max'),
        median_score=('borda_score', 'median'),
    )
    .reset_index()
    .sort_values('median_rank')
)
print(summary_quality.to_string())
# Out:
#     threshold_quantile   tail_family tail_exposure_mode bulk_exposure_mode  n_configs  median_rank  min_rank  max_rank  median_score
# 3                 0.70       weibull               free        free+weight         38         32.5       1.0     274.0     416685.75
# 2                 0.70       weibull               free               free         20         43.5       4.0     272.0     421084.25
# 6                 0.75           gpd        free+weight        free+weight         12        118.5      34.0     280.0     438170.50
# 1                 0.70           gpd        free+weight        free+weight         35        119.0      18.0     277.0     438512.50
# 0                 0.70           gpd        free+weight               free         19        121.0      40.0     275.0     438652.50
# 15                0.75       weibull               free               free          5        124.0      66.0     218.0     438852.50
# 5                 0.75           gpd        free+weight               free          8        124.5      63.0     265.0     439215.75
# 10                0.75  log_logistic               free        free+weight          5        137.0      84.0     262.0     440779.00
# 13                0.75  log_logistic             weight               free          6        140.5      96.0     208.0     440798.50
# 4                 0.75           gpd               free        free+weight          5        141.0      79.0     266.0     441238.00
# 16                0.75       weibull               free        free+weight         14        143.0      30.0     261.0     440691.50
# 18                0.80           gpd        free+weight        free+weight         18        146.5      23.0     276.0     441756.50
# 8                 0.75           gpd             weight        free+weight          8        147.0     111.0     225.0     441558.25
# 24                0.85           gpd        free+weight        free+weight          8        154.5      85.0     263.0     442273.75
# 12                0.75  log_logistic        free+weight        free+weight          8        161.5     126.0     192.0     442678.50
# 20                0.80  log_logistic        free+weight               free          4        174.0     131.0     267.0     443625.00
# 14                0.75  log_logistic             weight        free+weight         22        176.0      55.0     270.0     444013.50
# 25                0.85  log_logistic        free+weight        free+weight          5        179.0      83.0     224.0     444339.00
# 17                0.80           gpd        free+weight               free         11        182.0      53.0     278.0     444553.50
# 21                0.80  log_logistic        free+weight        free+weight         11        196.0      89.0     281.0     445442.50
# 23                0.80       weibull               free        free+weight          6        202.5     135.0     244.0     445987.25
# 22                0.80  log_logistic             weight        free+weight          1        227.0     227.0     227.0     447888.00
# 11                0.75  log_logistic        free+weight               free          7        228.0     171.0     253.0     448071.00
# 7                 0.75           gpd             weight               free          3        268.0     229.5     271.0     450221.50
# 9                 0.75  log_logistic               free               free          1        273.0     273.0     273.0     450627.50
# 19                0.80           gpd             weight        free+weight          1        279.0     279.0     279.0     450800.50

# %%
topsis_df, _   = topsis_rank(df_oos,   metrics_present, calib_present, verbose=False)
top_topsis_df = topsis_df[topsis_df['topsis_rank'] <= 200].copy()
summary_quality = (top_topsis_df
    .groupby(['threshold_quantile', 'tail_family', 'tail_exposure_mode', 'bulk_exposure_mode'])
    .agg(
        n_configs=('topsis_rank', 'count'),
        median_rank=('topsis_rank', 'median'),
        min_rank=('topsis_rank', 'min'),
        max_rank=('topsis_rank', 'max'),
        median_score=('topsis_score', 'median'),
    )
    .reset_index()
    .sort_values('median_rank')
)
print(summary_quality.to_string())
# Out:
#    threshold_quantile   tail_family tail_exposure_mode bulk_exposure_mode  n_configs  median_rank  min_rank  max_rank  median_score
# 5                0.85  log_logistic             weight        free+weight         68         63.5       1.0     178.0      0.734186
# 1                0.85           gpd        free+weight        free+weight         17         86.0      32.0     199.0      0.728662
# 4                0.85  log_logistic             weight               free         56         90.0      13.0     195.0      0.727939
# 0                0.85           gpd        free+weight               free         13        116.0      57.0     184.0      0.722925
# 3                0.85  log_logistic        free+weight        free+weight         36        159.0      84.0     197.0      0.716083
# 2                0.85  log_logistic        free+weight               free         10        183.5     133.0     200.0      0.712867

# %%
import json

def decode_cov_columns(df):
    for stage in ['s1', 's2', 'bulk', 'tail']:
        col = f'{stage}_cov'
        for cov in ['basin', 'is_island', 'sdi', 'wind_speed']:
            df[f'{stage}_{cov}'] = df[col].apply(
                lambda x: (x if isinstance(x, dict) else json.loads(x)).get(cov, False)
            )
    return df

top_topsis_df = decode_cov_columns(top_topsis_df)
top_borda_df = decode_cov_columns(top_borda_df)

# %%
# Decode cov JSON for each stage
import json

# Get the covariate pattern as a tuple for each stage
for stage in ['s1', 's2', 'bulk', 'tail']:
    covs = ['basin', 'is_island', 'sdi', 'wind_speed']
    top_topsis_df[f'{stage}_pattern'] = top_topsis_df.apply(
        lambda row: '+'.join(c for c in covs if row[f'{stage}_{c}']), axis=1
    )

# Summary by full covariate chain
chain_summary = (top_topsis_df
    .groupby(['s1_pattern', 's2_pattern', 'bulk_pattern', 'tail_pattern'])
    .agg(
        n=('topsis_rank', 'count'),
        median_rank=('topsis_rank', 'median'),
        min_rank=('topsis_rank', 'min'),
    )
    .reset_index()
    .sort_values('median_rank')
)
print(chain_summary.head(20).to_string())
# Out:
#                         s1_pattern                      s2_pattern                    bulk_pattern    tail_pattern  n  median_rank  min_rank
# 29  basin+is_island+sdi+wind_speed  basin+is_island+sdi+wind_speed        is_island+sdi+wind_speed   is_island+sdi  2          8.5       2.0
# 25  basin+is_island+sdi+wind_speed  basin+is_island+sdi+wind_speed                   is_island+sdi   is_island+sdi  2          9.0       5.0
# 45  basin+is_island+sdi+wind_speed            basin+sdi+wind_speed            basin+sdi+wind_speed             sdi  2         10.0       6.0
# 77            basin+sdi+wind_speed  basin+is_island+sdi+wind_speed        is_island+sdi+wind_speed   is_island+sdi  2         10.0       1.0
# 64            basin+sdi+wind_speed  basin+is_island+sdi+wind_speed  basin+is_island+sdi+wind_speed   is_island+sdi  2         11.0       4.0
# 15  basin+is_island+sdi+wind_speed  basin+is_island+sdi+wind_speed  basin+is_island+sdi+wind_speed   is_island+sdi  2         11.5       3.0
# 52  basin+is_island+sdi+wind_speed            basin+sdi+wind_speed                  sdi+wind_speed             sdi  2         13.5      10.0
# 73            basin+sdi+wind_speed  basin+is_island+sdi+wind_speed                   is_island+sdi   is_island+sdi  2         15.0       8.0
# 61            basin+sdi+wind_speed  basin+is_island+sdi+wind_speed             basin+is_island+sdi   is_island+sdi  2         16.0      11.0
# 11  basin+is_island+sdi+wind_speed  basin+is_island+sdi+wind_speed             basin+is_island+sdi   is_island+sdi  2         17.5       9.0
# 92            basin+sdi+wind_speed            basin+sdi+wind_speed            basin+sdi+wind_speed             sdi  2         18.0       7.0
# 99            basin+sdi+wind_speed            basin+sdi+wind_speed                  sdi+wind_speed             sdi  2         18.5      12.0
# 50  basin+is_island+sdi+wind_speed            basin+sdi+wind_speed                             sdi             sdi  2         34.0      24.0
# 58            basin+sdi+wind_speed             basin+is_island+sdi                   is_island+sdi   is_island+sdi  2         35.0      16.0
# 8   basin+is_island+sdi+wind_speed             basin+is_island+sdi                   is_island+sdi   is_island+sdi  2         37.0      23.0
# 97            basin+sdi+wind_speed            basin+sdi+wind_speed                             sdi             sdi  2         40.0      35.0
# 43  basin+is_island+sdi+wind_speed            basin+sdi+wind_speed                       basin+sdi             sdi  2         42.0      41.0
# 5   basin+is_island+sdi+wind_speed             basin+is_island+sdi             basin+is_island+sdi   is_island+sdi  2         42.0      28.0
# 55            basin+sdi+wind_speed             basin+is_island+sdi             basin+is_island+sdi   is_island+sdi  2         47.0      30.0
# 93            basin+sdi+wind_speed            basin+sdi+wind_speed            basin+sdi+wind_speed  sdi+wind_speed  2         47.5      38.0

# %%
# Decode cov JSON for each stage
import json

# Get the covariate pattern as a tuple for each stage
for stage in ['s1', 's2', 'bulk', 'tail']:
    covs = ['basin', 'is_island', 'sdi', 'wind_speed']
    top_borda_df[f'{stage}_pattern'] = top_borda_df.apply(
        lambda row: '+'.join(c for c in covs if row[f'{stage}_{c}']), axis=1
    )

# Summary by full covariate chain
chain_summary = (top_borda_df
    .groupby(['s1_pattern', 's2_pattern', 'bulk_pattern', 'tail_pattern'])
    .agg(
        n=('borda_rank', 'count'),
        median_rank=('borda_rank', 'median'),
        min_rank=('borda_rank', 'min'),
    )
    .reset_index()
    .sort_values('median_rank')
)
print(chain_summary.head(20).to_string())
# Out:
#                         s1_pattern                      s2_pattern                    bulk_pattern          tail_pattern  n  median_rank  min_rank
# 50            basin+sdi+wind_speed  basin+is_island+sdi+wind_speed            basin+sdi+wind_speed  basin+sdi+wind_speed  3         19.0      13.0
# 36            basin+sdi+wind_speed  basin+is_island+sdi+wind_speed             basin+is_island+sdi             basin+sdi  2         22.5       8.0
# 68            basin+sdi+wind_speed            basin+sdi+wind_speed                       basin+sdi             basin+sdi  6         32.5       3.0
# 13  basin+is_island+sdi+wind_speed  basin+is_island+sdi+wind_speed            basin+sdi+wind_speed  basin+sdi+wind_speed  2         34.0      33.0
# 18  basin+is_island+sdi+wind_speed            basin+sdi+wind_speed                       basin+sdi             basin+sdi  4         38.0      11.0
# 43            basin+sdi+wind_speed  basin+is_island+sdi+wind_speed  basin+is_island+sdi+wind_speed  basin+sdi+wind_speed  3         41.0      10.0
# 72            basin+sdi+wind_speed            basin+sdi+wind_speed            basin+sdi+wind_speed             basin+sdi  9         42.0       1.0
# 3   basin+is_island+sdi+wind_speed  basin+is_island+sdi+wind_speed             basin+is_island+sdi             basin+sdi  2         49.0      26.0
# 42            basin+sdi+wind_speed  basin+is_island+sdi+wind_speed  basin+is_island+sdi+wind_speed             basin+sdi  4         54.0      12.0
# 35            basin+sdi+wind_speed  basin+is_island+sdi+wind_speed             basin+is_island+sdi   basin+is_island+sdi  2         55.5      25.0
# 49            basin+sdi+wind_speed  basin+is_island+sdi+wind_speed            basin+sdi+wind_speed             basin+sdi  4         63.0      15.0
# 22  basin+is_island+sdi+wind_speed            basin+sdi+wind_speed            basin+sdi+wind_speed             basin+sdi  8         64.5       7.0
# 67            basin+sdi+wind_speed            basin+sdi+wind_speed                       basin+sdi                 basin  3         67.0      38.0
# 7   basin+is_island+sdi+wind_speed  basin+is_island+sdi+wind_speed  basin+is_island+sdi+wind_speed             basin+sdi  3         71.0      22.0
# 73            basin+sdi+wind_speed            basin+sdi+wind_speed            basin+sdi+wind_speed  basin+sdi+wind_speed  8         72.5       2.0
# 84            basin+sdi+wind_speed            basin+sdi+wind_speed                  sdi+wind_speed        sdi+wind_speed  7         74.0      44.0
# 2   basin+is_island+sdi+wind_speed  basin+is_island+sdi+wind_speed             basin+is_island+sdi   basin+is_island+sdi  2         74.5      43.0
# 34            basin+sdi+wind_speed  basin+is_island+sdi+wind_speed             basin+is_island+sdi                 basin  1         75.0      75.0
# 21  basin+is_island+sdi+wind_speed            basin+sdi+wind_speed            basin+sdi+wind_speed                 basin  2         80.5      57.0
# 8   basin+is_island+sdi+wind_speed  basin+is_island+sdi+wind_speed  basin+is_island+sdi+wind_speed  basin+sdi+wind_speed  3         82.0      27.0
