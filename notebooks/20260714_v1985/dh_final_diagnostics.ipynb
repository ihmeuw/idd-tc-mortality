# %% [markdown]
# # DH Final Diagnostics — 20260714_v1985 (post-2000 final grid)
#
# Final-selection notebook for the **256-config final grid** at
# `02-evaluate/20260714_v1985_final/` (model_predictions pending — initial run used --skip-model-predictions; the trimmed-ratio / IS-OOS section needs the no-skip rerun). Fork of
# `20260515/dh_final_diagnostics_post2000.ipynb`, repointed at the new
# re-fit-pipeline run.
#
# The storm-level machinery here — `mid` reconstruction → per-row prediction
# loaders → drop-top-N trimmed calibration → IS/OOS divergence → picking table —
# is the point of this stage: it arbitrates the winner where the aggregate
# ranking can't. (The refined ranking favoured configs pinned at the
# calibration-gate floor, i.e. heavy aggregate under-prediction; trimmed,
# storm-level calibration is what separates them.)
#
# **Convergence gate removed:** the re-fit-in-evaluate pipeline has no fit stage
# and writes no per-component `.json` sidecars, so that gate (present in the
# 20260517 version) is dropped.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from idd_tc_mortality.select.model_query import ModelQuery
from idd_tc_mortality.select.model_selection import (
    CONFIG_COLS,
    DEFAULT_METRICS,
    CALIBRATION_METRICS,
    prepare_rankings_df,
    borda_rank,
    pareto_frontier,
    topsis_rank,
    pairwise_dominance_summary,
    cluster_configurations,
    winner_profile,
    kendall_tau_heatmap,
    prune_redundant_metrics
)
from idd_tc_mortality.viz.stage_plots import StagePlotter

# Reuse the qmd's helper module for shared heatmap / winner-panel plots.
sys.path.insert(0, str(Path('../..').resolve() / 'reports'))
import _helpers as H

# %matplotlib inline
plt.rcParams['figure.dpi'] = 100
pd.options.display.max_columns = 80
pd.options.display.width = 160

# %% [markdown]
# ## Paths
#
# Edit the dates to point at the refined run you want to inspect.

# %%
ROOT      = Path('/mnt/team/idd/pub/idd_tc_mortality')
EVAL_DATE = '20260714_v1985_final'   # 4,608-config final-grid evaluate dir
DATA_DATE = '20260714_v1985'         # post-2000 input.parquet (years >= 2000)

RESULTS_PATH   = ROOT / '02-evaluate' / EVAL_DATE / 'dh_results.parquet'
EVAL_DIR       = ROOT / '02-evaluate' / EVAL_DATE
DATA_PATH      = ROOT / '00-data'     / DATA_DATE / 'input.parquet'
MODEL_PRED_DIR = EVAL_DIR / 'model_predictions'
# Re-fit pipeline writes the manifest into the evaluate dir (no separate fit stage).
MANIFEST_PATH  = EVAL_DIR / 'manifest.json'

for p in (RESULTS_PATH, EVAL_DIR, DATA_PATH, MODEL_PRED_DIR, MANIFEST_PATH):
    assert p.exists(), f'Missing: {p}'
print('All paths resolve.')
print(f'  model_predictions parquets: {len(list(MODEL_PRED_DIR.glob("*.parquet")))}')
# Out:
# All paths resolve.
#   model_predictions parquets: 27648

# %% [markdown]
# ## Load

# %%
dh_results = pd.read_parquet(RESULTS_PATH)
data       = pd.read_parquet(DATA_PATH)

print(f'dh_results : {dh_results.shape[0]:,} rows × {dh_results.shape[1]} cols')
print(f'training   : {data.shape[0]:,} rows × {data.shape[1]} cols')
print(f'fold_tags  : {dh_results["fold_tag"].value_counts().to_dict()}')
print(f'configs    : {dh_results.groupby(CONFIG_COLS, dropna=False).ngroups:,} unique')
print(f'thresholds : {sorted(dh_results["threshold_quantile"].unique())}')
# Out:
# dh_results : 27,648 rows × 252 cols
# training   : 3,024 rows × 13 cols
# fold_tags  : {'insample': 4608, 'oos_seed0': 4608, 'oos_seed1': 4608, 'oos_seed2': 4608, 'oos_seed3': 4608, 'oos_seed4': 4608}
# configs    : 4,608 unique
# thresholds : [np.float64(0.7), np.float64(0.75), np.float64(0.85)]

# %% [markdown]
# ## Build the rankings dataframe
#
# `prepare_rankings_df(..., subset='oos')` gives one row per config with OOS
# metrics averaged across seeds. This is the canonical input to all ranking
# methods below.
#
# Then we cull: drop configs with any non-finite OOS metric (failed folds)
# and configs outside the calibration gate. Tighten or loosen the cull as
# needed.

# %%
df_oos = prepare_rankings_df(dh_results, subset='oos')
print(f'{len(df_oos):,} configurations before any cull')
# Out:
# 4,608 configurations before any cull

# %%
print(f'Before cull: {len(df_oos):,} configs')

# Drop configs with any non-finite OOS metric (failed folds).
oos_numeric = [c for c in df_oos.columns
               if c.endswith('_oos') and pd.api.types.is_numeric_dtype(df_oos[c])]
finite_mask = np.isfinite(df_oos[oos_numeric].to_numpy()).all(axis=1)
n_failed = int((~finite_mask).sum())
df_oos = df_oos[finite_mask].copy()
print(f'After non-finite cull: {len(df_oos):,} configs ({n_failed:,} dropped as failures)')

# Asymmetric calibration gate — under-prediction (mega-event honesty)
# allowed; over-prediction (compensating bulk overpred) capped tighter.
# See preliminary_decisions_post2000.qmd §Scope.
RATIO_BOUNDS = (0.05, 1.1)
df_oos = df_oos[df_oos['full_pred_obs_ratio_oos'].between(*RATIO_BOUNDS)].copy()
print(f'After calibration gate [{RATIO_BOUNDS[0]}, {RATIO_BOUNDS[1]}]: '
      f'{len(df_oos):,} configs')

print('\nPost-cull count per threshold:')
print(df_oos['threshold_quantile'].value_counts().sort_index().to_string())
# Out:
# Before cull: 4,608 configs
# After non-finite cull: 4,608 configs (0 dropped as failures)
# After calibration gate [0.05, 1.1]: 3,840 configs
#
# Post-cull count per threshold:
# threshold_quantile
# 0.70    1536
# 0.75    1536
# 0.85     768

# %% [markdown]
# ### Convergence gate — N/A for the re-fit pipeline
#
# The 20260517 version scanned per-component `{component_id}.json` sidecars in the
# fit directory for an IRLS/optimiser `converged` flag. The re-fit-in-evaluate
# pipeline has **no fit stage and writes no sidecars** — components are re-fit
# in-memory by the evaluate worker and convergence is not persisted to
# `dh_results.parquet`. So this gate is dropped; `df_oos` after the calibration
# gate above is the candidate pool that feeds the storm-level diagnostics.

# %% [markdown]
# ## Per-rule winner trajectories
#
# Same diagnostic as the preliminary qmd's Threshold section, on the refined
# survivor pool. For each threshold, six configs are identified — the one
# that wins at coverage level 1, 5, 10, 15, 20 (argmax of
# `full_coverage_rate_L_oos`), and the one that wins on the mean across all
# 20 levels — and their full 1..20 trajectories are plotted. Each level-winner
# gets a dot at the level where it was picked.

# %%
winner_records = H.threshold_winner_panels(df_oos)
plt.show()

print('\nWinner configs per (threshold, rule):')
print(winner_records.to_string(index=False))
# Out:
# Winner configs per (threshold, rule):
#  threshold      rule s1_family s1_exposure_mode                                                               s1_cov s2_family s2_exposure_mode                                                               s2_cov  bulk_family bulk_exposure_mode                                                               bulk_cov  tail_family tail_exposure_mode                                                                tail_cov
#       0.70  best @ 1     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit               free {"basin": false, "is_island": false, "sdi": true, "wind_speed": false}      weibull               free   {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}
#       0.70  best @ 5     logit             free  {"basin": true, "is_island": true, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit               free  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false}          gpd             weight    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true}
#       0.70 best @ 10     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false}          gpd             weight    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true}
#       0.70 best @ 15     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight    {"basin": true, "is_island": true, "sdi": true, "wind_speed": true}          gpd             weight   {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}
#       0.70 best @ 20     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight   {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic             weight    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true}
#       0.70  best avg     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight   {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic             weight    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true}
#       0.75  best @ 1     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit               free {"basin": false, "is_island": false, "sdi": true, "wind_speed": false}      weibull               free  {"basin": false, "is_island": false, "sdi": true, "wind_speed": false}
#       0.75  best @ 5     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit               free  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false}          gpd             weight   {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}
#       0.75 best @ 10     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight   {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}          gpd             weight   {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}
#       0.75 best @ 15     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight  {"basin": false, "is_island": false, "sdi": true, "wind_speed": true} log_logistic        free+weight  {"basin": false, "is_island": false, "sdi": true, "wind_speed": false}
#       0.75 best @ 20     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free  {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight   {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic             weight    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true}
#       0.75  best avg     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight   {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic             weight    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true}
#       0.85  best @ 1     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit               free {"basin": false, "is_island": false, "sdi": true, "wind_speed": false}      weibull               free   {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}
#       0.85  best @ 5     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free  {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit               free  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false} log_logistic        free+weight {"basin": false, "is_island": false, "sdi": false, "wind_speed": false}
#       0.85 best @ 10     logit             free  {"basin": true, "is_island": true, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight   {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic        free+weight {"basin": false, "is_island": false, "sdi": false, "wind_speed": false}
#       0.85 best @ 15     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free  {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight    {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} log_logistic        free+weight {"basin": false, "is_island": false, "sdi": false, "wind_speed": false}
#       0.85 best @ 20     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free  {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight   {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic        free+weight {"basin": false, "is_island": false, "sdi": false, "wind_speed": false}
#       0.85  best avg     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free  {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight  {"basin": false, "is_island": false, "sdi": true, "wind_speed": true} log_logistic        free+weight {"basin": false, "is_island": false, "sdi": false, "wind_speed": false}

# %% [markdown]
# ## Per-row diagnostics — `mid` reconstruction
#
# `dh_results.parquet` stores spec attributes (family, exposure_mode, cov)
# but not the MD5 model_id used as the filename prefix in
# `model_predictions/`. Rebuild it once via a lookup against the refined
# manifest, then attach as a `mid` column on `df_oos`.
#
# The refined-final round reused the refined fits, so the right manifest
# is the one at `01-refined/20260517/manifest.json` (set above as
# `MANIFEST_PATH`).

# %%
import json
from idd_tc_mortality.cache import model_id as compute_model_id

manifest = json.loads(MANIFEST_PATH.read_text())

# Build a lookup: (component, threshold, family, exposure_mode, cov_str) -> full spec dict.
# threshold is None for s1. cov_str is the JSON of covariate_combo with sort_keys=True.
spec_lookup: dict[tuple, dict] = {}
for cid, spec in manifest.items():
    if not isinstance(spec, dict):
        continue
    if spec.get('fold_tag', 'is') != 'is':
        continue
    cov_str = json.dumps(spec.get('covariate_combo', {}), sort_keys=True)
    key = (
        spec.get('component'),
        spec.get('threshold_quantile'),  # None for s1
        spec.get('family'),
        spec.get('exposure_mode'),
        cov_str,
    )
    spec_lookup[key] = spec


def _row_to_mid(row: pd.Series) -> str:
    """Look up the 4 component specs for this DH row, compute the model_id hash."""
    q = row['threshold_quantile']
    s1 = spec_lookup[('s1',   None, row['s1_family'],   row['s1_exposure_mode'],   row['s1_cov'])]
    s2 = spec_lookup[('s2',   q,    row['s2_family'],   row['s2_exposure_mode'],   row['s2_cov'])]
    bk = spec_lookup[('bulk', q,    row['bulk_family'], row['bulk_exposure_mode'], row['bulk_cov'])]
    tl = spec_lookup[('tail', q,    row['tail_family'], row['tail_exposure_mode'], row['tail_cov'])]
    return compute_model_id(s1, s2, bk, tl)


df_oos['mid'] = df_oos.apply(_row_to_mid, axis=1)
print(f'mid attached. {df_oos["mid"].nunique()} unique mids across {len(df_oos)} configs.')

# Sanity check: at least one mid's files should exist on disk.
test_mid = df_oos['mid'].iloc[0]
is_path  = MODEL_PRED_DIR / f'{test_mid}_insample_predictions.parquet'
print(f'sample IS pred file exists: {is_path.exists()} ({is_path.name})')
# Out:
# mid attached. 3840 unique mids across 3840 configs.
# sample IS pred file exists: True (4d2aa7b96acec851a2f01e0151702669_insample_predictions.parquet)

# %% [markdown]
# ## Per-config prediction loader
#
# Each config in the refined-final pool has 6 per-row prediction parquets:
# - 1 IS  (`<mid>_insample_predictions.parquet`)
# - 5 OOS seeds (`<mid>_oos_seed{0..4}_predictions.parquet`)
#
# The loaders below join each prediction frame back to `input.parquet` by
# row position so the storm/year/location metadata travels alongside
# `predicted_rate`.

# %%
# Aliased to match the loader's expectation.
obs = data

def _join_input(pred_df: pd.DataFrame) -> pd.DataFrame:
    """Attach input.parquet's metadata columns to a per-row prediction frame."""
    if len(pred_df) != len(obs):
        raise ValueError(
            f'prediction row count {len(pred_df)} != input row count {len(obs)}'
        )
    out = obs.copy()
    out['predicted_rate'] = pred_df['predicted_rate'].values
    for col in ('heldout_fold_tag', 'threshold_rate', 'fold_tag'):
        if col in pred_df.columns:
            out[col] = pred_df[col].values
    return out


def load_is_pred(mid: str) -> pd.DataFrame:
    p = MODEL_PRED_DIR / f'{mid}_insample_predictions.parquet'
    return _join_input(pd.read_parquet(p))


def load_oos_pred(mid: str) -> pd.DataFrame:
    """Load all 5 OOS-seed predictions, joined to input metadata, with `seed` col."""
    frames = []
    for seed in range(5):
        p = MODEL_PRED_DIR / f'{mid}_oos_seed{seed}_predictions.parquet'
        if not p.exists():
            continue
        joined = _join_input(pd.read_parquet(p))
        joined['seed'] = seed
        frames.append(joined)
    return pd.concat(frames, ignore_index=True) if frames else pd.DataFrame()

# %% [markdown]
# ## Drop-top-N trimmed calibration ratio
#
# For every config in the post-cull pool, recompute the obs/pred ratio
# after dropping the top-N storms by observed deaths. Sweep N ∈
# {0, 5, 10, 25}. Three column families produced:
#
# - `trim_n=*_is`         — IS ratio per N
# - `trim_n=*_oos_mean`   — OOS ratio, mean across 5 seeds
# - `trim_n=*_oos_median` — OOS ratio, median across 5 seeds
#
# A config whose `trim_n=0` is near 1 but `trim_n=5` is far from 1 (or
# vice versa) is exposed as either mega-event-only or bulk-only
# calibrated. We want configs that stay near 1 across the N sweep.

# %%
# Trimmed-ratio sweep over the post-cull pool. Rewritten 2026-07-20 for the
# 4,608-config grid: read each config's 6 parquets once (June version re-read
# them per N), build the per-storm table once per (config, seed) and slice per
# N, and fan configs over a process pool — the pandas work is GIL-bound, so
# threads don't scale here. Measured ~1-2 min for ~3,800 configs.
from concurrent.futures import ProcessPoolExecutor, as_completed

N_SWEEP = [0, 5, 10, 25]
N_WORKERS = 12


def _per_storm(pred_df: pd.DataFrame) -> pd.DataFrame:
    """Per-storm observed vs predicted deaths, sorted by observed desc."""
    pred_df = pred_df.assign(pred_deaths=pred_df['predicted_rate'] * pred_df['exposed'])
    return (pred_df.groupby('storm_id', as_index=False)
            .agg(obs=('deaths', 'sum'), pred=('pred_deaths', 'sum'))
            .sort_values('obs', ascending=False))


def _trimmed(per_storm: pd.DataFrame, drop_top_n: int) -> float:
    keep = per_storm.iloc[drop_top_n:]
    denom = keep['obs'].sum()
    return float(keep['pred'].sum() / denom) if denom > 0 else float('nan')


def trimmed_ratios_one_config(mid: str) -> list:
    """All N_SWEEP trimmed ratios (IS + per-seed OOS) for one config."""
    is_df = load_is_pred(mid)
    ps_is = None if is_df.empty else _per_storm(is_df)
    oos = load_oos_pred(mid)
    ps_seeds = [] if (oos.empty or 'predicted_rate' not in oos.columns) else [
        _per_storm(sdf) for _, sdf in oos.groupby('seed')
    ]
    rows = []
    for n in N_SWEEP:
        per_seed = [_trimmed(ps, n) for ps in ps_seeds]
        rows.append({
            'mid': mid,
            'drop_top_n': n,
            'ratio_mean':   float(np.nanmean(per_seed)) if per_seed else float('nan'),
            'ratio_median': float(np.nanmedian(per_seed)) if per_seed else float('nan'),
            'ratio_is':     _trimmed(ps_is, n) if ps_is is not None else float('nan'),
        })
    return rows


records = []
mids = df_oos['mid'].tolist()
with ProcessPoolExecutor(max_workers=N_WORKERS) as pool:
    futures = [pool.submit(trimmed_ratios_one_config, m) for m in mids]
    for i, fut in enumerate(as_completed(futures), start=1):
        records.extend(fut.result())
        if i % 500 == 0 or i == len(mids):
            print(f'  trimmed-ratio: {i}/{len(mids)} configs done')
# Out:
#   trimmed-ratio: 500/3840 configs done
#   trimmed-ratio: 1000/3840 configs done
#   trimmed-ratio: 1500/3840 configs done
#   trimmed-ratio: 2000/3840 configs done
#   trimmed-ratio: 2500/3840 configs done
#   trimmed-ratio: 3000/3840 configs done
#   trimmed-ratio: 3500/3840 configs done
#   trimmed-ratio: 3840/3840 configs done

# %%
recs = pd.DataFrame(records)

trim_df_mean   = recs.pivot(index='mid', columns='drop_top_n', values='ratio_mean')
trim_df_median = recs.pivot(index='mid', columns='drop_top_n', values='ratio_median')
trim_df_is     = recs.pivot(index='mid', columns='drop_top_n', values='ratio_is')

trim_df_mean.columns   = [f'trim_n={n}_oos_mean'   for n in trim_df_mean.columns]
trim_df_median.columns = [f'trim_n={n}_oos_median' for n in trim_df_median.columns]
trim_df_is.columns     = [f'trim_n={n}_is'         for n in trim_df_is.columns]

# Merge all three column families onto df_oos by mid.
df_oos = (df_oos
    .merge(trim_df_is,     left_on='mid', right_index=True, how='left')
    .merge(trim_df_mean,   left_on='mid', right_index=True, how='left')
    .merge(trim_df_median, left_on='mid', right_index=True, how='left')
)

trim_df = trim_df_median   # canonical: matches the median-aggregation of the screening gate
print(f'Trim columns merged onto df_oos. Total cols now: {df_oos.shape[1]}')
# Out:
# Trim columns merged onto df_oos. Total cols now: 145

# %% [markdown]
# ## IS / OOS divergence
#
# For each config and each N, `is_oos_ratio_n=*` = `trim_n=*_is` /
# `trim_n=*_oos_median`. Close to 1 = IS calibration carries to OOS
# without surprises. Far from 1 = the config calibrates IS by being
# right on the storms it overfits to, and that doesn't generalise.
#
# Reported per-config:
# - `is_oos_max_log_dev`  — max |log(is/oos)| across the N sweep
# - `is_oos_mean_log_dev` — mean |log(is/oos)| across the N sweep

# %%
for n in N_SWEEP:
    df_oos[f'is_oos_ratio_n={n}'] = (
        df_oos[f'trim_n={n}_is'] / df_oos[f'trim_n={n}_oos_median']
    )

ratio_cols = [f'is_oos_ratio_n={n}' for n in N_SWEEP]
df_oos['is_oos_max_log_dev']  = np.abs(np.log(df_oos[ratio_cols])).max(axis=1)
df_oos['is_oos_mean_log_dev'] = np.abs(np.log(df_oos[ratio_cols])).mean(axis=1)

# Same diagnostic on the trim-OOS-median itself (max |log(trim_median)| across N).
log_dev = np.abs(np.log(df_oos[[f'trim_n={n}_oos_median' for n in N_SWEEP]]))
df_oos['oos_median_max_log_dev']  = log_dev.max(axis=1)
df_oos['oos_median_mean_log_dev'] = log_dev.mean(axis=1)
print('IS/OOS divergence columns attached.')
# Out:
# IS/OOS divergence columns attached.

# %%
df_oos['trim_n=25_oos_median'].max()
# Out:
# np.float64(2.238755454502281)

# %% [markdown]
# ## Pick your own metrics
#
# The 13-metric `DEFAULT_METRICS` is just a starting point. Edit the dict
# below — comment / uncomment lines — to define the set used downstream.
# Both the Kendall heatmap and the ranking step use whatever you set as
# `metrics_present` and `calib_present` here.
#
# Direction:
# - `'lower'`  → smaller is better
# - `'higher'` → larger is better
# - `'calib'`  → closer to 1.0 is better (handled separately by the ranking API)

# %%
metrics_to_use = {
    # ---- S1 (binary: P(deaths >= 1)) ----
    's1_auroc_oos':                  'higher',
    # 's1_brier_oos':                'lower',
    # 's1_fpr_oos':                  'lower',
    # 's1_fnr_oos':                  'lower',

    # ---- S2 (binary: P(rate >= thresh | deaths >= 1)) ----
    's2_auroc_oos':                  'higher',
    # 's2_brier_oos':                'lower',

    # ---- Bulk (regression on rate < thresh) ----
    'bulk_mae_rate_oos':             'lower',
    # 'bulk_rmse_rate_oos':          'lower',
    # 'bulk_cor_rate_oos':           'higher',

    # ---- Tail (regression on rate >= thresh) ----
    # 'tail_mae_rate_oos':             'lower',
    # 'tail_rmse_rate_oos':          'lower',
    # 'tail_cor_rate_oos':           'higher',

    # ---- Full (unconditional E[rate], applies to every row) ----
    'full_mae_rate_oos':             'lower',
    # 'full_rmse_rate_oos':            'lower',
    # 'full_cor_rate_oos':             'higher',
    # 'full_zero_acc_oos':             'higher',
    'full_pred_obs_ratio_oos':       'calib',
    'full_coverage_rate_20_oos':     'higher',
    'full_coverage_count_20_oos':     'higher',

    # ---- Forward (stage-conditional aggregate) ----
    # 'fwd_mae_rate_oos':              'lower',
    #'fwd_pred_obs_ratio_oos':        'calib',
    'fwd_coverage_rate_20_oos':      'higher',
    'fwd_coverage_count_20_oos':      'higher',

    # ---- IS/OOS divergence (diagnostic, not a selection metric) ----
    'trim_n=10_oos_median':         'calib',
    'trim_n=10_is':         'calib',
}

calib_present   = [k for k, v in metrics_to_use.items()
                   if v == 'calib' and k in df_oos.columns]
# metrics_present = {k: v for k, v in metrics_to_use.items()
#                    if v != 'calib' and k in df_oos.columns}
metrics_present = {k: v for k, v in metrics_to_use.items()
                   if k in df_oos.columns}

print(f'Active rank metrics ({len(metrics_present)}):')
for m, d in metrics_present.items():
    print(f'  {m:35s}  {d}')
print(f'\nActive calibration metrics ({len(calib_present)}):')
for c in calib_present:
    print(f'  {c}  (closer to 1.0)')

missing = [k for k in metrics_to_use if k not in df_oos.columns]
if missing:
    print(f'\n[note] {len(missing)} requested metrics not in df_oos (skipped): {missing}')
# Out:
# Active rank metrics (11):
#   s1_auroc_oos                         higher
#   s2_auroc_oos                         higher
#   bulk_mae_rate_oos                    lower
#   full_mae_rate_oos                    lower
#   full_pred_obs_ratio_oos              calib
#   full_coverage_rate_20_oos            higher
#   full_coverage_count_20_oos           higher
#   fwd_coverage_rate_20_oos             higher
#   fwd_coverage_count_20_oos            higher
#   trim_n=10_oos_median                 calib
#   trim_n=10_is                         calib
#
# Active calibration metrics (3):
#   full_pred_obs_ratio_oos  (closer to 1.0)
#   trim_n=10_oos_median  (closer to 1.0)
#   trim_n=10_is  (closer to 1.0)

# %% [markdown]
# ## Kendall τ — metric correlation
#
# Rank correlation between metrics on the culled candidate pool. Tightly
# correlated metrics (high τ) are redundant for ranking purposes; an
# uncorrelated metric adds independent information.

# %%
print(f'Computing rank correlations on {len(df_oos):,} configs × '
      f'{len(metrics_present)} metrics')
tau_df = kendall_tau_heatmap(df_oos, metrics_present, calib_present)
metrics_present, prune_log = prune_redundant_metrics(tau_df, metrics_present, threshold=0.7)
tau_df = kendall_tau_heatmap(df_oos, metrics_present, calib_present)
plt.show()
# Out:
# Computing rank correlations on 3,840 configs × 11 metrics
# === Metric Agreement Analysis ===
# Average pairwise Kendall tau: 0.016
# Pairs with negative correlation: 26
# Low agreement. Flat top tier may be aggregation artifact (metric cancellation).
# step 1: |τ|=0.738  full_mae_rate_oos (0.297) vs full_coverage_rate_20_oos (0.245)  → drop full_mae_rate_oos
# step 2: |τ|=0.719  full_pred_obs_ratio_oos (0.211) vs trim_n=10_is (0.190)  → drop full_pred_obs_ratio_oos
# step 3: |τ|=0.715  s2_auroc_oos (0.214) vs bulk_mae_rate_oos (0.202)  → drop s2_auroc_oos
# === Metric Agreement Analysis ===
# Average pairwise Kendall tau: 0.015
# Pairs with negative correlation: 12
# Low agreement. Flat top tier may be aggregation artifact (metric cancellation).

# %% [markdown]
# ## Winners by method
#
# Borda → TOPSIS → Pareto frontier (first row) → pairwise dominance. Each
# method picks one top config; the table compares them on a shared metric set.

# %%
borda_df, _    = borda_rank(df_oos,    metrics_present, calib_present)
top_borda_df = borda_df[borda_df['borda_rank'] <= 233].copy()
# table of quantile, tail_family, and covariate configuration
summary_quality = (top_borda_df
    .groupby(['threshold_quantile', 'tail_family', 'tail_exposure_mode', 'bulk_exposure_mode'])
    .agg(
        n_configs=('borda_rank', 'count'),
        median_rank=('borda_rank', 'median'),
        min_rank=('borda_rank', 'min'),
        max_rank=('borda_rank', 'max'),
        median_score=('borda_score', 'median'),
    )
    .reset_index()
    .sort_values('median_rank')
)
print(summary_quality.to_string())
# Out:
# === Borda Count Summary ===
# Total models: 3840
# Metrics used: 8
# Suggested cutpoint: rank 194 (top 194 models)
# Top tier Borda range: 7837.0 - 10217.0
# Bottom tier starts at: 10239.5
#    threshold_quantile   tail_family tail_exposure_mode bulk_exposure_mode  n_configs  median_rank  min_rank  max_rank  median_score
# 3                0.70  log_logistic        free+weight        free+weight         18        51.00       1.0     233.0       8933.00
# 6                0.75  log_logistic        free+weight               free         19        52.00      13.0     231.0       8931.50
# 2                0.70  log_logistic        free+weight               free         19        65.00       3.0     220.5       9067.00
# 7                0.75  log_logistic        free+weight        free+weight         16        74.50      22.0     229.0       9116.75
# 0                0.70           gpd             weight               free         40        91.25       8.0     225.0       9329.50
# 4                0.70  log_logistic             weight               free         54       113.00      12.0     232.0       9553.25
# 9                0.75  log_logistic             weight        free+weight         12       133.50      84.0     191.5       9692.50
# 5                0.70  log_logistic             weight        free+weight         23       138.00      33.0     224.0       9722.50
# 8                0.75  log_logistic             weight               free         11       143.00      87.0     211.0       9767.50
# 1                0.70           gpd             weight        free+weight         21       164.00      32.0     226.0       9968.00

# %%
topsis_df, _   = topsis_rank(df_oos,   metrics_present, calib_present, verbose=False)
top_topsis_df = topsis_df[topsis_df['topsis_rank'] <= 200].copy()
summary_quality = (top_topsis_df
    .groupby(['threshold_quantile', 'tail_family', 'tail_exposure_mode', 'bulk_exposure_mode'])
    .agg(
        n_configs=('topsis_rank', 'count'),
        median_rank=('topsis_rank', 'median'),
        min_rank=('topsis_rank', 'min'),
        max_rank=('topsis_rank', 'max'),
        median_score=('topsis_score', 'median'),
    )
    .reset_index()
    .sort_values('median_rank')
)
print(summary_quality.to_string())
# Out:
#     threshold_quantile   tail_family tail_exposure_mode bulk_exposure_mode  n_configs  median_rank  min_rank  max_rank  median_score
# 10                0.75  log_logistic             weight               free         17         44.0      14.0     198.0      0.723711
# 3                 0.70  log_logistic        free+weight        free+weight         12         54.0      45.0     100.0      0.717332
# 11                0.75  log_logistic             weight        free+weight         27         79.0       1.0     200.0      0.709482
# 5                 0.70  log_logistic             weight        free+weight         13         84.0      56.0     194.0      0.708776
# 9                 0.75  log_logistic        free+weight        free+weight         31         98.0       5.0     178.0      0.706930
# 2                 0.70  log_logistic        free+weight               free         20         99.5      61.0     188.0      0.707170
# 8                 0.75  log_logistic        free+weight               free         26        103.5       4.0     195.0      0.706646
# 0                 0.70           gpd             weight               free         13        118.0      75.0     185.0      0.704742
# 4                 0.70  log_logistic             weight               free         19        131.0      60.0     191.0      0.702949
# 7                 0.75           gpd             weight        free+weight         12        133.0      96.0     179.0      0.702803
# 6                 0.75           gpd             weight               free          6        161.0     148.0     167.0      0.698736
# 1                 0.70           gpd             weight        free+weight          4        194.5     184.0     199.0      0.695641

# %%
import json

def decode_cov_columns(df):
    for stage in ['s1', 's2', 'bulk', 'tail']:
        col = f'{stage}_cov'
        for cov in ['basin', 'is_island', 'sdi', 'wind_speed']:
            df[f'{stage}_{cov}'] = df[col].apply(
                lambda x: (x if isinstance(x, dict) else json.loads(x)).get(cov, False)
            )
    return df

top_topsis_df = decode_cov_columns(top_topsis_df)
top_borda_df = decode_cov_columns(top_borda_df)

# %%
# Decode cov JSON for each stage
import json

# Get the covariate pattern as a tuple for each stage
for stage in ['s1', 's2', 'bulk', 'tail']:
    covs = ['basin', 'is_island', 'sdi', 'wind_speed']
    top_topsis_df[f'{stage}_pattern'] = top_topsis_df.apply(
        lambda row: '+'.join(c for c in covs if row[f'{stage}_{c}']), axis=1
    )

# Summary by full covariate chain
chain_summary = (top_topsis_df
    .groupby(['s1_pattern', 's2_pattern', 'bulk_pattern', 'tail_pattern'])
    .agg(
        n=('topsis_rank', 'count'),
        median_rank=('topsis_rank', 'median'),
        min_rank=('topsis_rank', 'min'),
    )
    .reset_index()
    .sort_values('median_rank')
)
print(chain_summary.head(20).to_string())
# Out:
#               s1_pattern                      s2_pattern                    bulk_pattern   tail_pattern   n  median_rank  min_rank
# 41  basin+sdi+wind_speed            basin+sdi+wind_speed                             sdi  is_island+sdi   9         45.0      13.0
# 16  basin+sdi+wind_speed  basin+is_island+sdi+wind_speed                             sdi  is_island+sdi   9         50.0      16.0
# 19  basin+sdi+wind_speed  basin+is_island+sdi+wind_speed                  sdi+wind_speed  is_island+sdi   9         55.0       8.0
# 28  basin+sdi+wind_speed            basin+sdi+wind_speed                       basin+sdi  is_island+sdi  10         56.5       3.0
# 2   basin+sdi+wind_speed  basin+is_island+sdi+wind_speed  basin+is_island+sdi+wind_speed  is_island+sdi   9         57.0       6.0
# 5   basin+sdi+wind_speed  basin+is_island+sdi+wind_speed                       basin+sdi  is_island+sdi   9         58.0      27.0
# 23  basin+sdi+wind_speed            basin+sdi+wind_speed  basin+is_island+sdi+wind_speed  is_island+sdi  10         60.5       7.0
# 32  basin+sdi+wind_speed            basin+sdi+wind_speed            basin+sdi+wind_speed  is_island+sdi  10         61.5       9.0
# 37  basin+sdi+wind_speed            basin+sdi+wind_speed        is_island+sdi+wind_speed  is_island+sdi  10         61.5       1.0
# 46  basin+sdi+wind_speed            basin+sdi+wind_speed                  sdi+wind_speed  is_island+sdi  10         63.0       5.0
# 12  basin+sdi+wind_speed  basin+is_island+sdi+wind_speed        is_island+sdi+wind_speed  is_island+sdi   9         67.0       2.0
# 8   basin+sdi+wind_speed  basin+is_island+sdi+wind_speed            basin+sdi+wind_speed  is_island+sdi  10         80.5      22.0
# 29  basin+sdi+wind_speed            basin+sdi+wind_speed                       basin+sdi            sdi   3         88.0      79.0
# 13  basin+sdi+wind_speed  basin+is_island+sdi+wind_speed        is_island+sdi+wind_speed            sdi   3         94.0      87.0
# 38  basin+sdi+wind_speed            basin+sdi+wind_speed        is_island+sdi+wind_speed            sdi   3        101.0      71.0
# 20  basin+sdi+wind_speed  basin+is_island+sdi+wind_speed                  sdi+wind_speed            sdi   3        102.0      98.0
# 7   basin+sdi+wind_speed  basin+is_island+sdi+wind_speed            basin+sdi+wind_speed      basin+sdi   1        109.0     109.0
# 34  basin+sdi+wind_speed            basin+sdi+wind_speed        is_island+sdi+wind_speed                  2        117.0     114.0
# 24  basin+sdi+wind_speed            basin+sdi+wind_speed  basin+is_island+sdi+wind_speed            sdi   3        123.0      81.0
# 47  basin+sdi+wind_speed            basin+sdi+wind_speed                  sdi+wind_speed            sdi   4        130.5     111.0

# %%
# Decode cov JSON for each stage
import json

# Get the covariate pattern as a tuple for each stage
for stage in ['s1', 's2', 'bulk', 'tail']:
    covs = ['basin', 'is_island', 'sdi', 'wind_speed']
    top_borda_df[f'{stage}_pattern'] = top_borda_df.apply(
        lambda row: '+'.join(c for c in covs if row[f'{stage}_{c}']), axis=1
    )

# Summary by full covariate chain
chain_summary = (top_borda_df
    .groupby(['s1_pattern', 's2_pattern', 'bulk_pattern', 'tail_pattern'])
    .agg(
        n=('borda_rank', 'count'),
        median_rank=('borda_rank', 'median'),
        min_rank=('borda_rank', 'min'),
    )
    .reset_index()
    .sort_values('median_rank')
)
print(chain_summary.head(20).to_string())
# Out:
#               s1_pattern                      s2_pattern                    bulk_pattern                    tail_pattern   n  median_rank  min_rank
# 70  basin+sdi+wind_speed            basin+sdi+wind_speed                             sdi                   is_island+sdi   9        34.50       1.0
# 32  basin+sdi+wind_speed  basin+is_island+sdi+wind_speed                             sdi  basin+is_island+sdi+wind_speed   4        50.00      25.0
# 35  basin+sdi+wind_speed  basin+is_island+sdi+wind_speed                             sdi                   is_island+sdi   9        52.00       2.0
# 39  basin+sdi+wind_speed  basin+is_island+sdi+wind_speed                  sdi+wind_speed            basin+sdi+wind_speed   2        60.00      59.0
# 52  basin+sdi+wind_speed            basin+sdi+wind_speed                       basin+sdi                   is_island+sdi   8        60.50      19.0
# 67  basin+sdi+wind_speed            basin+sdi+wind_speed                             sdi  basin+is_island+sdi+wind_speed   4        61.00      51.0
# 40  basin+sdi+wind_speed  basin+is_island+sdi+wind_speed                  sdi+wind_speed                   is_island+sdi   8        63.00       6.0
# 59  basin+sdi+wind_speed            basin+sdi+wind_speed            basin+sdi+wind_speed                   is_island+sdi   9        67.00       3.0
# 69  basin+sdi+wind_speed            basin+sdi+wind_speed                             sdi            basin+sdi+wind_speed   2        70.00      69.0
# 73  basin+sdi+wind_speed            basin+sdi+wind_speed                  sdi+wind_speed  basin+is_island+sdi+wind_speed   4        73.00      32.0
# 18  basin+sdi+wind_speed  basin+is_island+sdi+wind_speed                       basin+sdi            basin+sdi+wind_speed   2        74.00      46.0
# 65  basin+sdi+wind_speed            basin+sdi+wind_speed        is_island+sdi+wind_speed                   is_island+sdi   9        75.00      10.0
# 50  basin+sdi+wind_speed            basin+sdi+wind_speed                       basin+sdi                       basin+sdi   1        77.00      77.0
# 56  basin+sdi+wind_speed            basin+sdi+wind_speed            basin+sdi+wind_speed  basin+is_island+sdi+wind_speed   3        82.00      57.0
# 76  basin+sdi+wind_speed            basin+sdi+wind_speed                  sdi+wind_speed                   is_island+sdi  10        83.00       9.0
# 34  basin+sdi+wind_speed  basin+is_island+sdi+wind_speed                             sdi            basin+sdi+wind_speed   4        83.00      40.0
# 38  basin+sdi+wind_speed  basin+is_island+sdi+wind_speed                  sdi+wind_speed                       basin+sdi   2        84.00      45.0
# 51  basin+sdi+wind_speed            basin+sdi+wind_speed                       basin+sdi            basin+sdi+wind_speed   2        84.50      68.0
# 14  basin+sdi+wind_speed  basin+is_island+sdi+wind_speed  basin+is_island+sdi+wind_speed                   is_island+sdi   7        86.00      18.0
# 26  basin+sdi+wind_speed  basin+is_island+sdi+wind_speed        is_island+sdi+wind_speed  basin+is_island+sdi+wind_speed   4        87.75      78.0

# %% [markdown]
# ## Picking table
#
# Top configs by `topsis_rank`, with all stage covs / family-exposure
# choices and the storm-level diagnostics in one place. Sort and filter
# this table interactively — the pick rule is **not** baked in.
#
# Columns of interest for the "no worse than any other" defense:
# - `topsis_rank`               — composite rank on the metric pool
# - `full_coverage_rate_*_oos`  — uncertainty coverage at chosen level
# - `trim_n=*_oos_median`       — calibration robustness across drop-top-N
# - `is_oos_max_log_dev`        — IS-to-OOS calibration transfer
# - `oos_median_max_log_dev`    — calibration stability across the N sweep

# %%
df_oos.head()
# Out:
#    threshold_quantile s1_family s1_exposure_mode s2_family s2_exposure_mode   bulk_family bulk_exposure_mode tail_family tail_exposure_mode  \
# 0                 0.7     logit             free     logit             free  scaled_logit               free         gpd             weight
# 1                 0.7     logit             free     logit             free  scaled_logit               free         gpd             weight
# 2                 0.7     logit             free     logit             free  scaled_logit               free         gpd             weight
# 3                 0.7     logit             free     logit             free  scaled_logit               free         gpd             weight
# 4                 0.7     logit             free     logit             free  scaled_logit               free         gpd             weight
#
#                                               s1_cov                                             s2_cov                                           bulk_cov  \
# 0  {"basin": true, "is_island": false, "sdi": tru...  {"basin": true, "is_island": false, "sdi": tru...  {"basin": false, "is_island": false, "sdi": tr...
# 1  {"basin": true, "is_island": false, "sdi": tru...  {"basin": true, "is_island": false, "sdi": tru...  {"basin": false, "is_island": false, "sdi": tr...
# 2  {"basin": true, "is_island": false, "sdi": tru...  {"basin": true, "is_island": false, "sdi": tru...  {"basin": false, "is_island": false, "sdi": tr...
# 3  {"basin": true, "is_island": false, "sdi": tru...  {"basin": true, "is_island": false, "sdi": tru...  {"basin": false, "is_island": false, "sdi": tr...
# 4  {"basin": true, "is_island": false, "sdi": tru...  {"basin": true, "is_island": false, "sdi": tru...  {"basin": false, "is_island": false, "sdi": tr...
#
#                                             tail_cov  s1_brier_oos  s1_auroc_oos  s1_fpr_oos  s1_fnr_oos  s1_predicted_positive_rate_oos  s2_brier_oos  \
# 0  {"basin": false, "is_island": false, "sdi": fa...      0.159701      0.796824    0.103574    0.521558                        0.216008      0.100066
# 1  {"basin": false, "is_island": false, "sdi": fa...      0.159701      0.796824    0.103574    0.521558                        0.216008      0.100066
# 2  {"basin": false, "is_island": false, "sdi": tr...      0.159701      0.796824    0.103574    0.521558                        0.216008      0.100066
# 3  {"basin": false, "is_island": true, "sdi": tru...      0.159701      0.796824    0.103574    0.521558                        0.216008      0.100066
# 4  {"basin": false, "is_island": true, "sdi": tru...      0.159701      0.796824    0.103574    0.521558                        0.216008      0.100066
#
#    s2_auroc_oos  s2_fpr_oos  s2_fnr_oos  s2_predicted_positive_rate_oos  bulk_mae_rate_oos  bulk_rmse_rate_oos  bulk_cor_rate_oos  bulk_mae_count_oos  \
# 0      0.919151    0.071779    0.305642                        0.259451       2.998539e-07        4.726369e-07           0.557287           30.392439
# 1      0.919151    0.071779    0.305642                        0.259451       2.998539e-07        4.726369e-07           0.557287           30.392439
# 2      0.919151    0.071779    0.305642                        0.259451       2.998539e-07        4.726369e-07           0.557287           30.392439
# 3      0.919151    0.071779    0.305642                        0.259451       2.998539e-07        4.726369e-07           0.557287           30.392439
# 4      0.919151    0.071779    0.305642                        0.259451       2.998539e-07        4.726369e-07           0.557287           30.392439
#
#    bulk_rmse_count_oos  bulk_cor_count_oos  tail_mae_rate_oos  tail_rmse_rate_oos  tail_cor_rate_oos  tail_mae_count_oos  tail_rmse_count_oos  \
# 0            87.472122            0.448514           0.001272            0.005444      -6.285379e-18         1240.852516          7216.726136
# 1            87.472122            0.448514           0.001273            0.005444      -1.252554e-01         1243.309934          7217.618862
# 2            87.472122            0.448514           0.001272            0.005444       5.390276e-02         1244.371749          7224.428889
# 3            87.472122            0.448514           0.001272            0.005444       7.999695e-03         1249.982779          7201.705412
# 4            87.472122            0.448514           0.001273            0.005444      -5.090849e-02         1249.435893          7182.416816
#
#    tail_cor_count_oos  fwd_mae_rate_oos  fwd_rmse_rate_oos  fwd_pred_obs_ratio_oos  fwd_coverage_rate_1_oos  fwd_coverage_count_1_oos  ...  \
# 0            0.531907          0.000383           0.003295                0.068094                      0.0                      0.20  ...
# 1            0.529822          0.000383           0.003295                0.068491                      0.0                      0.22  ...
# 2            0.519001          0.000383           0.003295                0.067798                      0.0                      0.20  ...
# 3            0.553174          0.000383           0.003295                0.076092                      0.0                      0.18  ...
# 4            0.558137          0.000383           0.003295                0.076756                      0.0                      0.16  ...
#
#    full_coverage_rate_13_oos  full_coverage_count_13_oos  full_coverage_rate_14_oos  full_coverage_count_14_oos  full_coverage_rate_15_oos  \
# 0                   0.315228                    0.447208                   0.320755                    0.461792                   0.332599
# 1                   0.311168                    0.448223                   0.317453                    0.463679                   0.324229
# 2                   0.315228                    0.448223                   0.323585                    0.460849                   0.332599
# 3                   0.327919                    0.427919                   0.334906                    0.449528                   0.346696
# 4                   0.317766                    0.431980                   0.326887                    0.454245                   0.342291
#
#    full_coverage_count_15_oos  full_coverage_rate_16_oos  full_coverage_count_16_oos  full_coverage_rate_17_oos  full_coverage_count_17_oos  \
# 0                    0.468722                   0.330165                    0.475620                   0.339806                    0.488932
# 1                    0.470044                   0.325207                    0.480165                   0.333981                    0.487379
# 2                    0.471366                   0.334711                    0.479752                   0.342913                    0.485049
# 3                    0.462115                   0.346281                    0.471074                   0.353010                    0.486214
# 4                    0.464758                   0.344628                    0.475207                   0.354951                    0.489320
#
#    full_coverage_rate_18_oos  full_coverage_count_18_oos  full_coverage_rate_19_oos  full_coverage_count_19_oos  full_coverage_rate_20_oos  \
# 0                   0.341651                    0.499817                   0.342957                    0.508522                   0.345785
# 1                   0.338716                    0.498349                   0.341217                    0.507826                   0.344132
# 2                   0.343853                    0.497248                   0.344348                    0.504348                   0.350744
# 3                   0.355229                    0.500183                   0.357217                    0.501913                   0.363636
# 4                   0.361468                    0.502018                   0.361739                    0.505043                   0.366281
#
#    full_coverage_count_20_oos  cor_ts_oos  beta_0_ts_oos  beta_p_ts_oos                               mid  trim_n=0_is  trim_n=5_is  trim_n=10_is  \
# 0                    0.518017    0.258153  -11499.044578      19.460250  4d2aa7b96acec851a2f01e0151702669     0.112746     0.567376      0.715856
# 1                    0.520992    0.258218  -11267.272370      19.547469  d9ba8aefebc0cab58bd08104a2991277     0.110763     0.555394      0.700650
# 2                    0.517355    0.248552   -9755.407230      17.930538  0c5e8e669c06cee33af002d84844445e     0.113004     0.567927      0.716453
# 3                    0.507769    0.239756   -7904.701417      13.962353  a875bcc3709272b778fe641b48565a63     0.128353     0.642144      0.809564
# 4                    0.514711    0.253808   -8484.139319      15.025145  60505dfd72d156bdda15337d5f0898e1     0.125595     0.614990      0.774859
#
#    trim_n=25_is  trim_n=0_oos_mean  trim_n=5_oos_mean  trim_n=10_oos_mean  trim_n=25_oos_mean  trim_n=0_oos_median  trim_n=5_oos_median  trim_n=10_oos_median  \
# 0      0.976907           0.113202           0.570941            0.720225            0.984513             0.113272             0.572512              0.722042
# 1      0.955318           0.111477           0.561337            0.708125            0.965890             0.111900             0.563516              0.710748
# 2      0.977437           0.112837           0.569557            0.718348            0.981976             0.113909             0.573747              0.723584
# 3      1.106393           0.131164           0.661245            0.832816            1.140987             0.131093             0.659151              0.831118
# 4      1.057662           0.125888           0.630614            0.793946            1.086286             0.126293             0.636509              0.802590
#
#    trim_n=25_oos_median  is_oos_ratio_n=0  is_oos_ratio_n=5  is_oos_ratio_n=10  is_oos_ratio_n=25  is_oos_max_log_dev  is_oos_mean_log_dev  \
# 0              0.988377          0.995361          0.991030           0.991432           0.988395            0.011673             0.008484
# 1              0.970165          0.989843          0.985587           0.985791           0.984696            0.015422             0.013615
# 2              0.990335          0.992059          0.989857           0.990145           0.986976            0.013110             0.010295
# 3              1.138762          0.979097          0.974199           0.974065           0.971575            0.028837             0.025595
# 4              1.098028          0.994470          0.966192           0.965447           0.963238            0.037455             0.028139
#
#    oos_median_max_log_dev  oos_median_mean_log_dev
# 0                2.177966                 0.768263
# 1                2.190154                 0.783860
# 2                2.172360                 0.765294
# 3                2.031846                 0.690894
# 4                2.069147                 0.708582
#
# [5 rows x 153 columns]

# %%
# Attach topsis_rank back onto df_oos (if not already there from earlier cells).
if 'topsis_rank' not in df_oos.columns:
    df_oos = df_oos.merge(
        topsis_df[CONFIG_COLS + ['topsis_rank', 'topsis_score']],
        on=CONFIG_COLS, how='left',
    )

# Columns to show in the picking table.
picking_cols = [
    'mid', 'threshold_quantile',
    's1_family', 's1_exposure_mode', 's1_cov',
    's2_family', 's2_exposure_mode', 's2_cov',
    'bulk_family', 'bulk_exposure_mode', 'bulk_cov',
    'tail_family', 'tail_exposure_mode', 'tail_cov',
    'topsis_rank', 'topsis_score',
    'full_pred_obs_ratio_oos',
    'full_coverage_rate_5_oos', 'full_coverage_rate_10_oos',
    'full_coverage_rate_20_oos',
    'trim_n=0_oos_median',  'trim_n=5_oos_median',
    'trim_n=10_oos_median', 'trim_n=25_oos_median',
    'trim_n=0_is',  'trim_n=5_is', 'trim_n=10_is', 'trim_n=25_is',
    'oos_median_max_log_dev', 'is_oos_max_log_dev',
]
picking_cols = [c for c in picking_cols if c in df_oos.columns]

picking_df = (df_oos[picking_cols]
              .sort_values('topsis_rank')
              .reset_index(drop=True))

# Default view: top 15 by topsis_rank. Re-sort interactively to view by other
# columns (e.g., picking_df.sort_values('oos_median_max_log_dev').head(10)).
TOP_N = 15
print(f'Top {TOP_N} by topsis_rank ({len(picking_df)} configs total):')
print()
print(picking_df.head(TOP_N).round(3).to_string(index=False))
# Out:
# Top 15 by topsis_rank (3840 configs total):
#
#                              mid  threshold_quantile s1_family s1_exposure_mode                                                               s1_cov s2_family s2_exposure_mode                                                               s2_cov  bulk_family bulk_exposure_mode                                                               bulk_cov  tail_family tail_exposure_mode                                                              tail_cov  topsis_rank  topsis_score  full_pred_obs_ratio_oos  full_coverage_rate_5_oos  full_coverage_rate_10_oos  full_coverage_rate_20_oos  trim_n=0_oos_median  trim_n=5_oos_median  trim_n=10_oos_median  trim_n=25_oos_median  trim_n=0_is  trim_n=5_is  trim_n=10_is  trim_n=25_is  oos_median_max_log_dev  is_oos_max_log_dev
# d2eace4143c908e2894f65a7f4c4dce5                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight   {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic             weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}          1.0         0.735                    0.148                     0.134                      0.273                      0.336                0.148                0.753                 0.946                 1.299        0.144        0.723         0.911         1.244                   1.910               0.043
# 68d4bda8079dc7ea6426e3571d002f59                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free  {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight   {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic             weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}          2.0         0.735                    0.151                     0.132                      0.271                      0.339                0.151                0.768                 0.965                 1.325        0.147        0.735         0.926         1.265                   1.891               0.046
# d49500eda0e54c2f4ed8dd0e874302c8                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false} log_logistic             weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}          3.0         0.734                    0.147                     0.134                      0.273                      0.334                0.147                0.751                 0.943                 1.296        0.144        0.721         0.908         1.241                   1.915               0.043
# 3d8eced18737a862b6fe2e93b2e138ba                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free  {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit               free   {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic        free+weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}          4.0         0.734                    0.150                     0.129                      0.272                      0.339                0.151                0.768                 0.967                 1.329        0.146        0.730         0.920         1.258                   1.892               0.055
# 9186558b791a568ad118d134f80f5497                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight  {"basin": false, "is_island": false, "sdi": true, "wind_speed": true} log_logistic        free+weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}          5.0         0.733                    0.151                     0.128                      0.277                      0.349                0.152                0.771                 0.971                 1.333        0.148        0.738         0.930         1.270                   1.886               0.048
# 0e4ce8d2e330a96193ec38d4ec106e83                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free  {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit               free    {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} log_logistic        free+weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}          6.0         0.731                    0.151                     0.126                      0.271                      0.340                0.152                0.774                 0.974                 1.338        0.147        0.736         0.927         1.266                   1.884               0.055
# 816fceb4f7a248dadf84459e104a0638                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight    {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} log_logistic             weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}          7.0         0.731                    0.147                     0.136                      0.273                      0.335                0.147                0.749                 0.941                 1.291        0.144        0.720         0.906         1.237                   1.915               0.043
# e41c03e1c0ad77f95b0b3a9416cb3b95                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free  {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight  {"basin": false, "is_island": false, "sdi": true, "wind_speed": true} log_logistic             weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}          8.0         0.731                    0.151                     0.132                      0.273                      0.340                0.151                0.768                 0.966                 1.325        0.147        0.735         0.926         1.265                   1.889               0.046
# 20e39d1360572b08df74be6704ed2329                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight   {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} log_logistic             weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}          9.0         0.731                    0.148                     0.136                      0.273                      0.335                0.148                0.750                 0.942                 1.293        0.144        0.720         0.907         1.238                   1.913               0.043
# 78394ccd015290b534526f7b75852354                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit               free  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false} log_logistic        free+weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         10.0         0.731                    0.148                     0.129                      0.274                      0.340                0.149                0.759                 0.955                 1.310        0.145        0.724         0.912         1.246                   1.905               0.050
# 77f893e80dccbaed01d8a7f512833605                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false} log_logistic        free+weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         11.0         0.730                    0.151                     0.126                      0.273                      0.346                0.151                0.769                 0.967                 1.329        0.147        0.736         0.927         1.267                   1.892               0.048
# 170f6d4e50b1982282b1e8aea6a72298                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free  {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight    {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} log_logistic             weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         12.0         0.730                    0.150                     0.132                      0.272                      0.338                0.150                0.764                 0.960                 1.317        0.146        0.732         0.921         1.257                   1.896               0.046
# 600ac3a9e5c93723e9368ebede5a551f                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight {"basin": false, "is_island": false, "sdi": true, "wind_speed": false} log_logistic        free+weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         13.0         0.730                    0.151                     0.128                      0.274                      0.347                0.151                0.771                 0.970                 1.333        0.147        0.737         0.929         1.269                   1.889               0.049
# ca7b0c110f93343759c58b535237350e                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit               free   {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} log_logistic             weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         14.0         0.730                    0.145                     0.141                      0.266                      0.329                0.145                0.738                 0.927                 1.269        0.141        0.707         0.891         1.217                   1.929               0.042
# 27a710c59cb8f0d2991d4ba5b475affb                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit               free   {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic        free+weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         15.0         0.730                    0.147                     0.130                      0.277                      0.341                0.148                0.753                 0.949                 1.300        0.144        0.718         0.906         1.237                   1.911               0.050

# %%
# Out:
#   Cell In[33], line 12
#     It should look like a column of this:
#        ^
# SyntaxError: invalid syntax

# %%
picking_df['tail_cov'].iloc[0]
# Out:
# '{"basin": false, "is_island": true, "sdi": true, "wind_speed": false}'

# %%
no_sdi_in_tail = picking_df[picking_df['tail_cov'] == '{"basin": false, "is_island": false, "sdi": false, "wind_speed": false}'].copy()
no_sdi_in_tail.head()
# Out:
#                                   mid  threshold_quantile s1_family s1_exposure_mode                                             s1_cov s2_family  \
# 111  5ce277186364590e4254d1f8ae65c782                0.75     logit             free  {"basin": true, "is_island": false, "sdi": tru...     logit
# 113  bade17b69632997546e33b506239d6c8                0.75     logit             free  {"basin": true, "is_island": false, "sdi": tru...     logit
# 119  61da263db0b0d101cb4cb15033fd6a9f                0.75     logit             free  {"basin": true, "is_island": false, "sdi": tru...     logit
# 127  2d36e1935b1c297fc48687690f17db37                0.75     logit             free  {"basin": true, "is_island": false, "sdi": tru...     logit
# 144  660c87cc554a275247a95bb0fe7a740a                0.75     logit             free  {"basin": true, "is_island": false, "sdi": tru...     logit
#
#     s2_exposure_mode                                             s2_cov   bulk_family bulk_exposure_mode                                           bulk_cov  \
# 111             free  {"basin": true, "is_island": false, "sdi": tru...  scaled_logit        free+weight  {"basin": true, "is_island": false, "sdi": tru...
# 113             free  {"basin": true, "is_island": false, "sdi": tru...  scaled_logit        free+weight  {"basin": false, "is_island": true, "sdi": tru...
# 119             free  {"basin": true, "is_island": false, "sdi": tru...  scaled_logit        free+weight  {"basin": false, "is_island": true, "sdi": tru...
# 127             free  {"basin": true, "is_island": false, "sdi": tru...  scaled_logit        free+weight  {"basin": true, "is_island": true, "sdi": true...
# 144             free  {"basin": true, "is_island": false, "sdi": tru...  scaled_logit        free+weight  {"basin": false, "is_island": false, "sdi": tr...
#
#       tail_family tail_exposure_mode                                           tail_cov  topsis_rank  topsis_score  full_pred_obs_ratio_oos  \
# 111  log_logistic             weight  {"basin": false, "is_island": false, "sdi": fa...        112.0      0.705657                 0.131709
# 113  log_logistic             weight  {"basin": false, "is_island": false, "sdi": fa...        114.0      0.705402                 0.132315
# 119  log_logistic        free+weight  {"basin": false, "is_island": false, "sdi": fa...        120.0      0.704404                 0.134656
# 127  log_logistic             weight  {"basin": false, "is_island": false, "sdi": fa...        128.0      0.703245                 0.131687
# 144  log_logistic        free+weight  {"basin": false, "is_island": false, "sdi": fa...        145.0      0.701022                 0.134802
#
#      full_coverage_rate_5_oos  full_coverage_rate_10_oos  full_coverage_rate_20_oos  trim_n=0_oos_median  trim_n=5_oos_median  trim_n=10_oos_median  \
# 111                  0.130263                   0.265347                   0.318017             0.131181             0.666392              0.839511
# 113                  0.126316                   0.266007                   0.320000             0.131812             0.668646              0.842302
# 119                  0.123684                   0.269307                   0.331570             0.133972             0.680076              0.857054
# 127                  0.127632                   0.267987                   0.316694             0.131087             0.664826              0.837204
# 144                  0.123684                   0.269307                   0.331240             0.134187             0.680499              0.857646
#
#      trim_n=25_oos_median  trim_n=0_is  trim_n=5_is  trim_n=10_is  trim_n=25_is  oos_median_max_log_dev  is_oos_max_log_dev
# 111              1.149363     0.130915     0.660701      0.832967      1.138695                2.031177            0.009325
# 113              1.151933     0.131617     0.663080      0.836012      1.141473                2.026382            0.009122
# 119              1.171697     0.133247     0.671073      0.846328      1.154979                2.010122            0.014371
# 127              1.144162     0.130956     0.659416      0.831098      1.133994                2.031894            0.008927
# 144              1.172439     0.133360     0.671293      0.846612      1.155421                2.008517            0.014621

# %%
cols = ['threshold_quantile',
        's1_family','s1_exposure_mode','s1_cov',
        's2_family','s2_exposure_mode','s2_cov',
        'bulk_family','bulk_exposure_mode','bulk_cov',
        'tail_family','tail_exposure_mode','tail_cov']
# This vintage's own top configs by TOPSIS rank. NOTE: a config's `mid` hash
# encodes the data-derived threshold_rate (the absolute rate a quantile maps
# to), so it differs per vintage — the 20260608 winner hashes do NOT appear in
# these grids even for an identical covariate/family config. Always derive the
# winners from this run's ranking, never by hardcoded mid.
import pandas as pd
pd.set_option('display.max_colwidth', None)

TOP_N = 3
mids = df_oos.sort_values('topsis_rank')['mid'].head(TOP_N).tolist()
for rank, m in enumerate(mids, start=1):
    r = df_oos[df_oos.mid == m].iloc[0]
    print(f'#{rank} topsis  mid={m}  q={r["threshold_quantile"]}')
    for c in ['s1_cov', 's2_cov', 'bulk_cov', 'tail_cov']:
        print('   ', c, '=', r[c])
# Out:
# #1 topsis  mid=d2eace4143c908e2894f65a7f4c4dce5  q=0.75
#     s1_cov = {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}
#     s2_cov = {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}
#     bulk_cov = {"basin": false, "is_island": true, "sdi": true, "wind_speed": true}
#     tail_cov = {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}
# #2 topsis  mid=68d4bda8079dc7ea6426e3571d002f59  q=0.75
#     s1_cov = {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}
#     s2_cov = {"basin": true, "is_island": true, "sdi": true, "wind_speed": true}
#     bulk_cov = {"basin": false, "is_island": true, "sdi": true, "wind_speed": true}
#     tail_cov = {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}
# #3 topsis  mid=d49500eda0e54c2f4ed8dd0e874302c8  q=0.75
#     s1_cov = {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}
#     s2_cov = {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}
#     bulk_cov = {"basin": true, "is_island": false, "sdi": true, "wind_speed": false}
#     tail_cov = {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}

# %%
# Alternate view: among the top-N by topsis_rank, re-sort by IS/OOS divergence
# to surface configs whose IS calibration transfers OOS most reliably.
N_SHORTLIST = 25
shortlist = picking_df.head(N_SHORTLIST).copy()
print(f'Among top {N_SHORTLIST} by topsis_rank, sorted by oos_median_max_log_dev:')
print()
print(shortlist
      .sort_values('oos_median_max_log_dev')
      .round(3)
      .to_string(index=False))
# Out:
# Among top 25 by topsis_rank, sorted by oos_median_max_log_dev:
#
#                              mid  threshold_quantile s1_family s1_exposure_mode                                                               s1_cov s2_family s2_exposure_mode                                                               s2_cov  bulk_family bulk_exposure_mode                                                               bulk_cov  tail_family tail_exposure_mode                                                              tail_cov  topsis_rank  topsis_score  full_pred_obs_ratio_oos  full_coverage_rate_5_oos  full_coverage_rate_10_oos  full_coverage_rate_20_oos  trim_n=0_oos_median  trim_n=5_oos_median  trim_n=10_oos_median  trim_n=25_oos_median  trim_n=0_is  trim_n=5_is  trim_n=10_is  trim_n=25_is  oos_median_max_log_dev  is_oos_max_log_dev
# 859c137c3d6d771ce188c871fd2efe12                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free  {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight {"basin": false, "is_island": false, "sdi": true, "wind_speed": false} log_logistic        free+weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         16.0         0.730                    0.154                     0.126                      0.271                      0.345                0.154                0.785                 0.988                 1.358        0.150        0.749         0.944         1.290                   1.871               0.051
# 0e4ce8d2e330a96193ec38d4ec106e83                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free  {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit               free    {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} log_logistic        free+weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}          6.0         0.731                    0.151                     0.126                      0.271                      0.340                0.152                0.774                 0.974                 1.338        0.147        0.736         0.927         1.266                   1.884               0.055
# 9186558b791a568ad118d134f80f5497                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight  {"basin": false, "is_island": false, "sdi": true, "wind_speed": true} log_logistic        free+weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}          5.0         0.733                    0.151                     0.128                      0.277                      0.349                0.152                0.771                 0.971                 1.333        0.148        0.738         0.930         1.270                   1.886               0.048
# 9e8cebf03d40864872325dec2afb0268                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free  {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit               free   {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} log_logistic        free+weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         22.0         0.729                    0.151                     0.126                      0.273                      0.340                0.152                0.772                 0.972                 1.334        0.147        0.734         0.925         1.263                   1.887               0.055
# 88be6896dcf0bb54afb4d1b022b07032                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight   {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic        free+weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         25.0         0.728                    0.151                     0.126                      0.277                      0.349                0.151                0.771                 0.970                 1.332        0.148        0.738         0.930         1.269                   1.888               0.048
# 600ac3a9e5c93723e9368ebede5a551f                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight {"basin": false, "is_island": false, "sdi": true, "wind_speed": false} log_logistic        free+weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         13.0         0.730                    0.151                     0.128                      0.274                      0.347                0.151                0.771                 0.970                 1.333        0.147        0.737         0.929         1.269                   1.889               0.049
# e41c03e1c0ad77f95b0b3a9416cb3b95                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free  {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight  {"basin": false, "is_island": false, "sdi": true, "wind_speed": true} log_logistic             weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}          8.0         0.731                    0.151                     0.132                      0.273                      0.340                0.151                0.768                 0.966                 1.325        0.147        0.735         0.926         1.265                   1.889               0.046
# 68d4bda8079dc7ea6426e3571d002f59                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free  {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight   {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic             weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}          2.0         0.735                    0.151                     0.132                      0.271                      0.339                0.151                0.768                 0.965                 1.325        0.147        0.735         0.926         1.265                   1.891               0.046
# 77f893e80dccbaed01d8a7f512833605                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false} log_logistic        free+weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         11.0         0.730                    0.151                     0.126                      0.273                      0.346                0.151                0.769                 0.967                 1.329        0.147        0.736         0.927         1.267                   1.892               0.048
# 3d8eced18737a862b6fe2e93b2e138ba                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free  {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit               free   {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic        free+weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}          4.0         0.734                    0.150                     0.129                      0.272                      0.339                0.151                0.768                 0.967                 1.329        0.146        0.730         0.920         1.258                   1.892               0.055
# 170f6d4e50b1982282b1e8aea6a72298                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free  {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} scaled_logit        free+weight    {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} log_logistic             weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         12.0         0.730                    0.150                     0.132                      0.272                      0.338                0.150                0.764                 0.960                 1.317        0.146        0.732         0.921         1.257                   1.896               0.046
# b7807716136dfc5f78e20c163ccf8991                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit               free    {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} log_logistic        free+weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         19.0         0.730                    0.148                     0.129                      0.277                      0.342                0.149                0.759                 0.956                 1.309        0.145        0.724         0.912         1.245                   1.903               0.050
# 78394ccd015290b534526f7b75852354                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit               free  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false} log_logistic        free+weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         10.0         0.731                    0.148                     0.129                      0.274                      0.340                0.149                0.759                 0.955                 1.310        0.145        0.724         0.912         1.246                   1.905               0.050
# 4d5f528654ff148ecbcb73f665d2a2a9                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit               free   {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} log_logistic        free+weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         18.0         0.730                    0.148                     0.129                      0.278                      0.344                0.149                0.757                 0.953                 1.306        0.144        0.722         0.910         1.242                   1.906               0.050
# 1d5cd6544d4a8cd21cd23b2fe9ad49f8                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight  {"basin": false, "is_island": false, "sdi": true, "wind_speed": true} log_logistic             weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         20.0         0.729                    0.148                     0.134                      0.273                      0.338                0.148                0.753                 0.947                 1.299        0.145        0.724         0.911         1.244                   1.909               0.043
# d2eace4143c908e2894f65a7f4c4dce5                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight   {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic             weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}          1.0         0.735                    0.148                     0.134                      0.273                      0.336                0.148                0.753                 0.946                 1.299        0.144        0.723         0.911         1.244                   1.910               0.043
# 27a710c59cb8f0d2991d4ba5b475affb                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit               free   {"basin": false, "is_island": true, "sdi": true, "wind_speed": true} log_logistic        free+weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         15.0         0.730                    0.147                     0.130                      0.277                      0.341                0.148                0.753                 0.949                 1.300        0.144        0.718         0.906         1.237                   1.911               0.050
# 568a20d8c9c8331138bd3653562438f3                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight {"basin": false, "is_island": false, "sdi": true, "wind_speed": false} log_logistic             weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         21.0         0.729                    0.148                     0.134                      0.274                      0.335                0.148                0.752                 0.946                 1.300        0.144        0.722         0.910         1.244                   1.912               0.044
# faad8314a7f8141b4eedb5eb89da0724                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit               free {"basin": false, "is_island": false, "sdi": true, "wind_speed": false} log_logistic        free+weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         24.0         0.729                    0.147                     0.129                      0.274                      0.340                0.148                0.753                 0.947                 1.300        0.143        0.718         0.905         1.236                   1.913               0.050
# 20e39d1360572b08df74be6704ed2329                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight   {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} log_logistic             weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}          9.0         0.731                    0.148                     0.136                      0.273                      0.335                0.148                0.750                 0.942                 1.293        0.144        0.720         0.907         1.238                   1.913               0.043
# d49500eda0e54c2f4ed8dd0e874302c8                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false} log_logistic             weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}          3.0         0.734                    0.147                     0.134                      0.273                      0.334                0.147                0.751                 0.943                 1.296        0.144        0.721         0.908         1.241                   1.915               0.043
# 816fceb4f7a248dadf84459e104a0638                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit        free+weight    {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} log_logistic             weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}          7.0         0.731                    0.147                     0.136                      0.273                      0.335                0.147                0.749                 0.941                 1.291        0.144        0.720         0.906         1.237                   1.915               0.043
# beded88f316bf023fc679c0cd39ea705                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit               free    {"basin": true, "is_island": true, "sdi": true, "wind_speed": true} log_logistic             weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         17.0         0.730                    0.145                     0.141                      0.267                      0.331                0.146                0.739                 0.930                 1.272        0.142        0.709         0.893         1.220                   1.926               0.042
# e48df5fdaa462a05c0e1377813f5d246                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit               free  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false} log_logistic             weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         23.0         0.729                    0.145                     0.141                      0.267                      0.330                0.145                0.739                 0.929                 1.273        0.141        0.709         0.893         1.221                   1.928               0.042
# ca7b0c110f93343759c58b535237350e                0.75     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}     logit             free {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} scaled_logit               free   {"basin": true, "is_island": false, "sdi": true, "wind_speed": true} log_logistic             weight {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}         14.0         0.730                    0.145                     0.141                      0.266                      0.329                0.145                0.738                 0.927                 1.269        0.141        0.707         0.891         1.217                   1.929               0.042

# %%
borda_df, _    = borda_rank(df_oos,    metrics_present, calib_present)
topsis_df, _   = topsis_rank(df_oos,   metrics_present, calib_present, verbose=False)
pareto_df      = pareto_frontier(df_oos, metrics_present, calib_present)
dominance_df   = pairwise_dominance_summary(df_oos, metrics_present, calib_present)

winners = {
    'borda':              borda_df.iloc[0],
    'topsis':             topsis_df.iloc[0],
    'pareto_first':       pareto_df.iloc[0],
    'pairwise_dominance': dominance_df.iloc[0],
}
show_cols = [c for c in CONFIG_COLS if c in df_oos.columns] + [
    'full_mae_rate_oos', 'full_cor_rate_oos',
    'full_pred_obs_ratio_oos', 'full_coverage_rate_10_oos',
    'fwd_mae_rate_oos', 'fwd_coverage_rate_10_oos',
    's1_auroc_oos',
]
# Out:
# === Borda Count Summary ===
# Total models: 3840
# Metrics used: 8
# Suggested cutpoint: rank 194 (top 194 models)
# Top tier Borda range: 7837.0 - 10217.0
# Bottom tier starts at: 10239.5
#
# === Pareto Frontier ===
# Total models: 3840
# Non-dominated: 2403 (62.6%)
# Dominated: 1437
# === Pairwise Dominance Summary ===
# Models compared: 3840
# Metrics used: 8
# Max dominance: 3396 / 3839 models beaten
# Median dominance: 971
#
# Top 10 most dominant models:
#    dominance_rank  dominance_count  dominance_pct  threshold_quantile s1_family s1_exposure_mode s2_family s2_exposure_mode   bulk_family bulk_exposure_mode   tail_family tail_exposure_mode                                                                s1_cov                                                                s2_cov                                                                bulk_cov                                                               tail_cov
# 0             1.0             3396      88.460537                0.70     logit             free     logit             free  scaled_logit        free+weight  log_logistic        free+weight  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}  {"basin": false, "is_island": false, "sdi": true, "wind_speed": false}  {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}
# 1             2.0             3352      87.314405                0.70     logit             free     logit             free  scaled_logit               free  log_logistic        free+weight  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}    {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}  {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}
# 2             3.0             3336      86.897630                0.70     logit             free     logit             free  scaled_logit               free  log_logistic        free+weight  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}   {"basin": true, "is_island": true, "sdi": true, "wind_speed": true}    {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}  {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}
# 3             4.0             3319      86.454806                0.70     logit             free     logit             free  scaled_logit        free+weight  log_logistic        free+weight  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}   {"basin": true, "is_island": true, "sdi": true, "wind_speed": true}  {"basin": false, "is_island": false, "sdi": true, "wind_speed": false}  {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}
# 4             5.0             3294      85.803595                0.70     logit             free     logit             free  scaled_logit               free  log_logistic        free+weight  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}   {"basin": true, "is_island": true, "sdi": true, "wind_speed": true}  {"basin": false, "is_island": false, "sdi": true, "wind_speed": false}  {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}
# 5             6.0             3284      85.543110                0.70     logit             free     logit             free  scaled_logit               free  log_logistic        free+weight  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}   {"basin": true, "is_island": true, "sdi": true, "wind_speed": true}   {"basin": false, "is_island": false, "sdi": true, "wind_speed": true}  {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}
# 6             7.0             3271      85.204480                0.70     logit             free     logit             free  scaled_logit               free  log_logistic        free+weight  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}  {"basin": false, "is_island": false, "sdi": true, "wind_speed": false}  {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}
# 7             8.0             3261      84.943996                0.75     logit             free     logit             free  scaled_logit        free+weight  log_logistic        free+weight  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}   {"basin": false, "is_island": false, "sdi": true, "wind_speed": true}  {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}
# 8             9.0             3251      84.683511                0.70     logit             free     logit             free  scaled_logit        free+weight  log_logistic        free+weight  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}    {"basin": false, "is_island": true, "sdi": true, "wind_speed": true}  {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}
# 9            10.0             3214      83.719719                0.75     logit             free     logit             free  scaled_logit        free+weight  log_logistic        free+weight  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}    {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}  {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}

# %%
show_cols = [c for c in show_cols if c in df_oos.columns]
winners_df = pd.DataFrame({k: w[show_cols] for k, w in winners.items()}).T

def _active(j):
    return ','.join(k for k, v in json.loads(j).items() if v) or '∅'
for c in ('s1_cov', 's2_cov', 'bulk_cov', 'tail_cov'):
    if c in winners_df.columns:
        winners_df[c] = winners_df[c].map(_active)
winners_df
# Out:
#                    threshold_quantile s1_family s1_exposure_mode s2_family s2_exposure_mode   bulk_family bulk_exposure_mode   tail_family tail_exposure_mode  \
# borda                             0.7     logit             free     logit             free  scaled_logit        free+weight  log_logistic        free+weight
# topsis                           0.75     logit             free     logit             free  scaled_logit        free+weight  log_logistic             weight
# pareto_first                      0.7     logit             free     logit             free  scaled_logit               free           gpd             weight
# pairwise_dominance                0.7     logit             free     logit             free  scaled_logit        free+weight  log_logistic        free+weight
#
#                                   s1_cov                s2_cov                  bulk_cov       tail_cov full_mae_rate_oos full_cor_rate_oos  \
# borda               basin,sdi,wind_speed  basin,sdi,wind_speed                       sdi  is_island,sdi          0.000115         -0.010981
# topsis              basin,sdi,wind_speed  basin,sdi,wind_speed  is_island,sdi,wind_speed  is_island,sdi          0.000116           -0.0011
# pareto_first        basin,sdi,wind_speed  basin,sdi,wind_speed                       sdi     wind_speed          0.000115         -0.024117
# pairwise_dominance  basin,sdi,wind_speed  basin,sdi,wind_speed                       sdi  is_island,sdi          0.000115         -0.010981
#
#                    full_pred_obs_ratio_oos full_coverage_rate_10_oos fwd_mae_rate_oos fwd_coverage_rate_10_oos s1_auroc_oos
# borda                             0.146522                  0.260066         0.000383                 0.169231     0.796824
# topsis                            0.148043                  0.273267         0.000383                  0.16044     0.796824
# pareto_first                      0.111477                  0.265347         0.000383                  0.10989     0.796824
# pairwise_dominance                0.146522                  0.260066         0.000383                 0.169231     0.796824

# %%
top_borda_mid = borda_df['mid'].head(5)
top_topsis_mid = topsis_df['mid'].head(5)
top_mid = set(top_borda_mid) | set(top_topsis_mid)
print(top_mid)
print(len(top_mid))
# Out:
# {'68d4bda8079dc7ea6426e3571d002f59', '53cf3bd5b3691dcd69cf59462b962b37', '718881001ca064653e40b862832006ac', '9186558b791a568ad118d134f80f5497', 'd2eace4143c908e2894f65a7f4c4dce5', 'd49500eda0e54c2f4ed8dd0e874302c8', '4cf216a4e36dd200e017830523dbd839', '9b8fdc0f8089c767b982821079d14714', '12043fda8734914b124bfb91f97f856b', '3d8eced18737a862b6fe2e93b2e138ba'}
# 10

# %%
topsis_df.head(5)
# Out:
#    threshold_quantile s1_family s1_exposure_mode s2_family s2_exposure_mode   bulk_family bulk_exposure_mode   tail_family tail_exposure_mode  \
# 0                0.75     logit             free     logit             free  scaled_logit        free+weight  log_logistic             weight
# 1                0.75     logit             free     logit             free  scaled_logit        free+weight  log_logistic             weight
# 2                0.75     logit             free     logit             free  scaled_logit        free+weight  log_logistic             weight
# 3                0.75     logit             free     logit             free  scaled_logit               free  log_logistic        free+weight
# 4                0.75     logit             free     logit             free  scaled_logit        free+weight  log_logistic        free+weight
#
#                                                                  s1_cov                                                                s2_cov  \
# 0  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}
# 1  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}   {"basin": true, "is_island": true, "sdi": true, "wind_speed": true}
# 2  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}
# 3  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}   {"basin": true, "is_island": true, "sdi": true, "wind_speed": true}
# 4  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}  {"basin": true, "is_island": false, "sdi": true, "wind_speed": true}
#
#                                                                 bulk_cov                                                               tail_cov  s1_brier_oos  \
# 0   {"basin": false, "is_island": true, "sdi": true, "wind_speed": true}  {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}      0.159701
# 1   {"basin": false, "is_island": true, "sdi": true, "wind_speed": true}  {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}      0.159701
# 2  {"basin": true, "is_island": false, "sdi": true, "wind_speed": false}  {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}      0.159701
# 3   {"basin": false, "is_island": true, "sdi": true, "wind_speed": true}  {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}      0.159701
# 4  {"basin": false, "is_island": false, "sdi": true, "wind_speed": true}  {"basin": false, "is_island": true, "sdi": true, "wind_speed": false}      0.159701
#
#    s1_auroc_oos  s1_fpr_oos  s1_fnr_oos  s1_predicted_positive_rate_oos  s2_brier_oos  s2_auroc_oos  s2_fpr_oos  s2_fnr_oos  s2_predicted_positive_rate_oos  \
# 0      0.796824    0.103574    0.521558                        0.216008      0.082831      0.925882    0.053574    0.303078                        0.214987
# 1      0.796824    0.103574    0.521558                        0.216008      0.083167      0.924585    0.051086    0.308804                        0.211791
# 2      0.796824    0.103574    0.521558                        0.216008      0.082831      0.925882    0.053574    0.303078                        0.214987
# 3      0.796824    0.103574    0.521558                        0.216008      0.083167      0.924585    0.051086    0.308804                        0.211791
# 4      0.796824    0.103574    0.521558                        0.216008      0.082831      0.925882    0.053574    0.303078                        0.214987
#
#    bulk_mae_rate_oos  bulk_rmse_rate_oos  bulk_cor_rate_oos  bulk_mae_count_oos  bulk_rmse_count_oos  bulk_cor_count_oos  tail_mae_rate_oos  \
# 0       4.791091e-07        7.869133e-07           0.523735           34.265781            93.097568            0.410992           0.001526
# 1       4.791091e-07        7.869133e-07           0.523735           34.265781            93.097568            0.410992           0.001526
# 2       4.764680e-07        7.642904e-07           0.537088           34.345515            93.931175            0.405861           0.001526
# 3       4.386974e-07        7.449940e-07           0.528625           33.740960            93.842527            0.434276           0.001528
# 4       4.774103e-07        7.833197e-07           0.526828           34.134075            92.973683            0.417920           0.001528
#
#    tail_rmse_rate_oos  tail_cor_rate_oos  tail_mae_count_oos  tail_rmse_count_oos  tail_cor_count_oos  fwd_mae_rate_oos  fwd_rmse_rate_oos  \
# 0            0.005963           0.046003         1515.747786          7912.860562            0.623814          0.000383           0.003295
# 1            0.005963           0.046003         1515.747786          7912.860562            0.623814          0.000383           0.003295
# 2            0.005963           0.046003         1515.747786          7912.860562            0.623814          0.000383           0.003295
# 3            0.005964          -0.044052         1515.180170          7909.555154            0.621992          0.000383           0.003295
# 4            0.005964          -0.044052         1515.180170          7909.555154            0.621992          0.000383           0.003295
#
#    fwd_pred_obs_ratio_oos  fwd_coverage_rate_1_oos  fwd_coverage_count_1_oos  ...  full_coverage_rate_14_oos  full_coverage_count_14_oos  \
# 0                0.085879                      0.0                      0.16  ...                   0.320755                    0.458019
# 1                0.087205                      0.0                      0.16  ...                   0.315094                    0.452830
# 2                0.083606                      0.0                      0.16  ...                   0.319340                    0.455189
# 3                0.085552                      0.0                      0.16  ...                   0.309906                    0.447170
# 4                0.088145                      0.0                      0.16  ...                   0.323585                    0.459906
#
#    full_coverage_rate_15_oos  full_coverage_count_15_oos  full_coverage_rate_16_oos  full_coverage_count_16_oos  full_coverage_rate_17_oos  \
# 0                   0.332159                    0.470044                   0.331818                    0.477273                   0.335922
# 1                   0.332159                    0.467401                   0.328512                    0.474793                   0.335922
# 2                   0.329956                    0.466960                   0.327686                    0.473967                   0.331262
# 3                   0.323348                    0.461233                   0.325207                    0.470248                   0.333981
# 4                   0.329075                    0.471806                   0.331818                    0.476446                   0.339417
#
#    full_coverage_count_17_oos  full_coverage_rate_18_oos  full_coverage_count_18_oos  full_coverage_rate_19_oos  full_coverage_count_19_oos  \
# 0                    0.486214                   0.340550                    0.493211                   0.341217                    0.497739
# 1                    0.486990                   0.339450                    0.496147                   0.342609                    0.497043
# 2                    0.481942                   0.336881                    0.489908                   0.337043                    0.498087
# 3                    0.480777                   0.336881                    0.493945                   0.337391                    0.498087
# 4                    0.484272                   0.346055                    0.492844                   0.346087                    0.499826
#
#    full_coverage_rate_20_oos  full_coverage_count_20_oos  cor_ts_oos  beta_0_ts_oos  beta_p_ts_oos                               mid  trim_n=0_is  \
# 0                   0.336198                    0.511736    0.217890   -4850.801639      10.213323  d2eace4143c908e2894f65a7f4c4dce5     0.144493
# 1                   0.339174                    0.509752    0.215024   -4623.626986       9.867996  68d4bda8079dc7ea6426e3571d002f59     0.146912
# 2                   0.334215                    0.507769    0.213617   -4468.299225       9.984897  d49500eda0e54c2f4ed8dd0e874302c8     0.143790
# 3                   0.339174                    0.510083    0.214808   -4460.127768       9.828236  3d8eced18737a862b6fe2e93b2e138ba     0.146057
# 4                   0.348760                    0.512727    0.215777   -4430.563943       9.718643  9186558b791a568ad118d134f80f5497     0.147757
#
#    trim_n=5_is  trim_n=10_is  trim_n=25_is  trim_n=0_oos_mean  trim_n=5_oos_mean  trim_n=10_oos_mean  trim_n=25_oos_mean  trim_n=0_oos_median  \
# 0     0.723312      0.910877      1.244005           0.148043           0.747724            0.940971            1.288636             0.148012
# 1     0.735261      0.926010      1.264978           0.150836           0.761853            0.958830            1.313400             0.150950
# 2     0.720933      0.907832      1.241227           0.147437           0.745813            0.938499            1.286559             0.147381
# 3     0.730254      0.920420      1.257593           0.149994           0.758312            0.955512            1.309667             0.150765
# 4     0.738350      0.930466      1.269810           0.151290           0.763950            0.962502            1.317912             0.151643
#
#    trim_n=5_oos_median  trim_n=10_oos_median  trim_n=25_oos_median  is_oos_ratio_n=0  is_oos_ratio_n=5  is_oos_ratio_n=10  is_oos_ratio_n=25  \
# 0             0.752789              0.946176              1.298708          0.976223          0.960843           0.962694           0.957879
# 1             0.767865              0.965157              1.324722          0.973248          0.957539           0.959440           0.954901
# 2             0.750535              0.943384              1.296138          0.975631          0.960558           0.962314           0.957635
# 3             0.768256              0.967012              1.329044          0.968773          0.950534           0.951819           0.946239
# 4             0.771345              0.970778              1.332719          0.974374          0.957224           0.958474           0.952796
#
#    is_oos_max_log_dev  is_oos_mean_log_dev  oos_median_max_log_dev  oos_median_mean_log_dev  topsis_rank  topsis_score
# 0            0.043034             0.036266                1.910462                 0.627782          1.0      0.735368
# 1            0.046148             0.039514                1.890808                 0.617904          2.0      0.735054
# 2            0.043288             0.036654                1.914731                 0.629843          3.0      0.734089
# 3            0.055260             0.046774                1.892034                 0.618418          4.0      0.733770
# 4            0.048354             0.040111                1.886228                 0.615682          5.0      0.733482
#
# [5 rows x 155 columns]

# %%
import json

def decode_cov_columns(df):
    df = df.copy()
    for stage in ['s1', 's2', 'bulk', 'tail']:
        col = f'{stage}_cov'
        for cov in ['basin', 'is_island', 'sdi', 'wind_speed']:
            df[f'{stage}_{cov}'] = df[col].apply(
                lambda x: (x if isinstance(x, dict) else json.loads(x)).get(cov, False)
            )
    return df

covs = ['basin', 'is_island', 'sdi', 'wind_speed']
df_oos = decode_cov_columns(df_oos)
for stage in ['s1', 's2', 'bulk', 'tail']:
    df_oos[f'{stage}_pattern'] = df_oos.apply(
        lambda row: '+'.join(c for c in covs if row[f'{stage}_{c}']) or '∅',
        axis=1,
    )

# %%
top_df = df_oos[df_oos['mid'].isin(top_mid)].copy()
top_df['mid_short'] = top_df['mid'].str[:8]


display_cols = [
    'mid_short', 'topsis_rank', 'topsis_score',
    'threshold_quantile',
    's1_family',   's1_exposure_mode',   's1_pattern',
    's2_family',   's2_exposure_mode',   's2_pattern',
    'bulk_family', 'bulk_exposure_mode', 'bulk_pattern',
    'tail_family', 'tail_exposure_mode', 'tail_pattern',
    'full_pred_obs_ratio_oos',
    'full_coverage_rate_5_oos', 'full_coverage_rate_10_oos', 'full_coverage_rate_20_oos',
    'trim_n=0_oos_median', 'trim_n=5_oos_median', 'trim_n=10_oos_median', 'trim_n=25_oos_median',
    'trim_n=0_is',  'trim_n=5_is',  'trim_n=10_is',  'trim_n=25_is',
    'oos_median_max_log_dev', 'is_oos_max_log_dev',
]
display_cols = [c for c in display_cols if c in top_df.columns]

top_df_view = (
    top_df[display_cols]
    .sort_values('topsis_rank')
    .reset_index(drop=True)
    .round(3)
)

# Set display width for the notebook so it doesn't wrap awkwardly.
import pandas as pd
with pd.option_context('display.max_columns', None,
                       'display.width', 220,
                       'display.max_colwidth', 30):
    print(top_df_view.to_string(index=False))
# Out:
# mid_short  topsis_rank  topsis_score  threshold_quantile s1_family s1_exposure_mode           s1_pattern s2_family s2_exposure_mode                     s2_pattern  bulk_family bulk_exposure_mode             bulk_pattern  tail_family tail_exposure_mode  tail_pattern  full_pred_obs_ratio_oos  full_coverage_rate_5_oos  full_coverage_rate_10_oos  full_coverage_rate_20_oos  trim_n=0_oos_median  trim_n=5_oos_median  trim_n=10_oos_median  trim_n=25_oos_median  trim_n=0_is  trim_n=5_is  trim_n=10_is  trim_n=25_is  oos_median_max_log_dev  is_oos_max_log_dev
#  d2eace41          1.0         0.735                0.75     logit             free basin+sdi+wind_speed     logit             free           basin+sdi+wind_speed scaled_logit        free+weight is_island+sdi+wind_speed log_logistic             weight is_island+sdi                    0.148                     0.134                      0.273                      0.336                0.148                0.753                 0.946                 1.299        0.144        0.723         0.911         1.244                   1.910               0.043
#  68d4bda8          2.0         0.735                0.75     logit             free basin+sdi+wind_speed     logit             free basin+is_island+sdi+wind_speed scaled_logit        free+weight is_island+sdi+wind_speed log_logistic             weight is_island+sdi                    0.151                     0.132                      0.271                      0.339                0.151                0.768                 0.965                 1.325        0.147        0.735         0.926         1.265                   1.891               0.046
#  d49500ed          3.0         0.734                0.75     logit             free basin+sdi+wind_speed     logit             free           basin+sdi+wind_speed scaled_logit        free+weight                basin+sdi log_logistic             weight is_island+sdi                    0.147                     0.134                      0.273                      0.334                0.147                0.751                 0.943                 1.296        0.144        0.721         0.908         1.241                   1.915               0.043
#  3d8eced1          4.0         0.734                0.75     logit             free basin+sdi+wind_speed     logit             free basin+is_island+sdi+wind_speed scaled_logit               free is_island+sdi+wind_speed log_logistic        free+weight is_island+sdi                    0.150                     0.129                      0.272                      0.339                0.151                0.768                 0.967                 1.329        0.146        0.730         0.920         1.258                   1.892               0.055
#  9186558b          5.0         0.733                0.75     logit             free basin+sdi+wind_speed     logit             free           basin+sdi+wind_speed scaled_logit        free+weight           sdi+wind_speed log_logistic        free+weight is_island+sdi                    0.151                     0.128                      0.277                      0.349                0.152                0.771                 0.971                 1.333        0.148        0.738         0.930         1.270                   1.886               0.048
#  4cf216a4         45.0         0.723                0.70     logit             free basin+sdi+wind_speed     logit             free           basin+sdi+wind_speed scaled_logit        free+weight                      sdi log_logistic        free+weight is_island+sdi                    0.147                     0.116                      0.260                      0.355                0.146                0.739                 0.932                 1.280        0.142        0.710         0.895         1.223                   1.923               0.046
#  53cf3bd5         50.0         0.721                0.70     logit             free basin+sdi+wind_speed     logit             free basin+is_island+sdi+wind_speed scaled_logit        free+weight                      sdi log_logistic        free+weight is_island+sdi                    0.149                     0.113                      0.260                      0.353                0.148                0.748                 0.944                 1.297        0.144        0.719         0.907         1.239                   1.910               0.046
#  71888100         61.0         0.713                0.70     logit             free basin+sdi+wind_speed     logit             free basin+is_island+sdi+wind_speed scaled_logit               free     basin+sdi+wind_speed log_logistic        free+weight is_island+sdi                    0.146                     0.117                      0.259                      0.349                0.145                0.732                 0.923                 1.268        0.141        0.704         0.888         1.213                   1.932               0.044
#  12043fda         63.0         0.713                0.70     logit             free basin+sdi+wind_speed     logit             free basin+is_island+sdi+wind_speed scaled_logit               free                      sdi log_logistic        free+weight is_island+sdi                    0.145                     0.116                      0.258                      0.350                0.145                0.731                 0.922                 1.267        0.141        0.703         0.887         1.212                   1.934               0.045
#  9b8fdc0f         64.0         0.712                0.70     logit             free basin+sdi+wind_speed     logit             free           basin+sdi+wind_speed scaled_logit               free     basin+sdi+wind_speed log_logistic        free+weight is_island+sdi                    0.144                     0.117                      0.259                      0.352                0.143                0.722                 0.911                 1.251        0.139        0.695         0.876         1.196                   1.945               0.045
